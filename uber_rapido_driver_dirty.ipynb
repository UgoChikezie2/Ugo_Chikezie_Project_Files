# %%
import pandas as pd

#import matplotlib.pyplot as plt

df = pd.read_csv("uber_rapido_driver_cleaned.csv")
df.head(5)
# Out:
#    driver_id       driver_name  age       city       phone  \
# 0  DRV993813    Naresh Chauhan   70    Chennai  9255500096
# 1  DRV937048        Amit Gupta   45  Ahmedabad  9940345570
# 2  DRV612651     Yogesh Nair     53    Lucknow  9170487337
# 3  DRV177713       Manoj Patel   46  Hyderabad  9246425981
# 4  DRV991919  Vikram Chaudhary   25    Kolkata     9282240
#
#                         email platform vehicle_type vehicle_condition  \
# 0  naresh.chauhan@hotmail.com     Uber         Auto              Good
# 1   amit.gupta@rediffmail.com     Uber        Mini          Excellent
# 2     Yogesh Nair  @gmail.com     Uber          Suv           Average
# 3     manoj.patel@hotmail.com   Rapido         Mini             Super
# 4  vikram.chaudhary@gmail.com    Uber           Suv              Good
#
#   experience_level  ... driving_test_score_10 route_knowledge_score_10  \
# 0           4+ yrs  ...                   4.3                      5.8
# ...

# %%
df.describe()
# Out:
#                 age         phone  overall_driver_rating  \
# count  50000.000000  5.000000e+04           50000.000000
# mean      68.330280  2.582512e+10               4.147626
# std      163.219465  3.364797e+10               1.503027
# min       20.000000  9.000153e+06               0.100000
# 25%       30.000000  9.246444e+09               3.200000
# 50%       40.000000  9.595512e+09               3.900000
# 75%       49.000000  9.938337e+09               4.700000
# max      999.000000  9.199984e+10               7.700000
#
#        total_trips_completed  trip_completion_rate_%  cancellation_rate_%  \
# count           50000.000000            50000.000000         50000.000000
# mean             4499.792100               77.677198            24.411158
# std              1444.488566               19.546249            23.481446
# min              2000.000000                0.100000            -2.000000
# 25%              3247.000000               70.600000             9.100000
# ...

# %%
df.shape
# Out:
# (50000, 33)

# %%
df['email'].unique()
# Out:
# array(['naresh.chauhan@hotmail.com', 'amit.gupta@rediffmail.com',
#        '  Yogesh Nair  @gmail.com', ..., 'deepak.srivastavahotmail.com',
#        'deepak.singhgmail.com', 'deepak.dubeygmail.com'], dtype=object)

# %%
df['email'] = df['email'].astype("string")
print(df['email'].dtype)
# Out:
# string

# %%
##This code creates a gmail adrress for the drivers using their names, where they have no existing emails.

df['email'] = df['email'].fillna(
    df['driver_name'] + '@gmail.com'
)
df.sample(1000)
# Out:
#        driver_id       driver_name  age       city        phone  \
# 15204  DRV252058      Naresh Singh   70    Kolkata  91781113690
# 2880   DRV520123     Vijay Chauhan   38       Pune  91834235321
# 49654  DRV269385     RAJESH TIWARI   54    Kolkata   9148860090
# 42384  DRV175697      Naveen Yadav   43      Delhi   9079354615
# 48907  DRV822661      Vikram Dubey  999       Pune   9973702061
# ...          ...               ...  ...        ...          ...
# 11831  DRV604613    Sanjay Chauhan   50       Pune   9475779388
# 25292  DRV814947    Harish Yadav     21  Bangalore   9638654837
# 29250  DRV112451    Rajesh Chauhan   24  Hyderabad   9554578953
# 15044  DRV213952     Deepak Shukla   36  Ahmedabad   9832835356
# 18685  DRV387606      R@mesh P@tel   33    Lucknow  91307905042
#
#                              email       platform vehicle_type  \
# 15204  naresh.singh@rediffmail.com          Uber          Auto
# 2880       vijay.chauhan@gmail.com  Uber & rapido         Auto
# ...

# %%
df.sample(10)
# Out:
#        driver_id           driver_name  age       city        phone  \
# 39549  DRV348583          Yogesh Singh   20  Bangalore   9883411661
# 46557  DRV745588         Hitesh Sharma   22  Ahmedabad   9025733012
# 41254  DRV306067    Girish Chaudhary     40    Chennai  91188259989
# 10726  DRV918377        Santosh Sharma   28  Bangalore   9540673042
# 39765  DRV174846         Harish Sharma   47  Ahmedabad   9593553648
# 25519  DRV274043         Sanjay Sharma   36  Hyderabad  91318026571
# 46736  DRV941357         Manoj Chauhan   48  Bangalore   9778495920
# 38688  DRV936822          NAVEEN SINGH   34  Hyderabad      9659376
# 16207  DRV010337            Harish Rao   43      Delhi  91715947489
# 44013  DRV051379          Ramesh Patel   70     Mumbai   9706845277
#
#                               email       platform vehicle_type  \
# 39549        yogesh.singh@yahoo.com           Uber        Mini
# 46557       hitesh.sharma@gmail.com  Uber & rapido          Suv
# ...

# %%
df['phone'] = pd.to_numeric(df['phone'], errors='coerce') 
## This is to convert the phone collumn from object to numeric

# %%
df['phone'] = df['phone'].astype("string")
print(df['phone'].dtype)
# Out:
# string

# %%
df['driving_test_score_10'].unique()
# Out:
# array([ 4.3,  9.3,  6.3,  8.7, 10. ,  8.8,  8.1,  1.1,  7.5,  7.4,  0.6,
#         7.7,  6.2,  4.8,  7.1,  0.9,  5.5,  8.9,  6.4,  5.1,  7. ,  7.6,
#         5.7,  9.1,  8.3,  4.6,  4. ,  7.2,  8. ,  9.7,  4.2,  9.5,  4.9,
#         5.8,  5. ,  6.9,  4.1,  6.5,  4.5,  9.8,  5.4,  4.4,  1.3,  9.2,
#         4.7,  7.3,  1.5,  8.6,  8.4,  1.7,  5.3,  6.1,  6. ,  9.6,  7.9,
#         6.8,  5.2,  5.6,  0.7,  9.4,  9.9,  7.8,  8.2,  6.6,  6.7,  9. ,
#         5.9,  8.5,  1. ,  0.8,  0.4,  0.5,  0.3,  1.8,  1.2,  0.2,  1.4,
#         1.6,  1.9,  0.1,  2. ])

# %%
## This code removes the decimals from the values and make them strings rather than floats. 
df['phone'] = df['phone'].str.replace(r'\.0$', '', regex=True)

# %%
## This creates random phone numbers for NaN values in the phone column

import numpy as np

mask = df['phone'].isna()

df.loc[mask, 'phone'] = [
    '+91' + ''.join(np.random.choice(list('0123456789'), 9))
    for _ in range(mask.sum())
]
df.sample(1000)
# Out:
#        driver_id       driver_name  age       city        phone  \
# 20494  DRV635439      Vijay Pandey   44      Delhi   9019227231
# 34608  DRV364571      Mukesh Verma   70      Delhi      9948716
# 27025  DRV102762  Pankaj Chaudhary   22  Bangalore  91526692718
# 2205   DRV903693  Sunil Srivastava   33      Delhi   9190600590
# 32004  DRV438475     Hitesh Tiwari   51  Hyderabad   9489499060
# ...          ...               ...  ...        ...          ...
# 44947  DRV835830      rajesh kumar   37  Hyderabad   9184024213
# 20625  DRV372516       Ravi Tiwari   31  Bangalore  91543829916
# 14974  DRV209374       Sanjay Nair   41    Chennai   9881401290
# 33362  DRV107703      Pradeep Nair   34      Delhi   9286141350
# 41517  DRV477330      Rakesh Patel   50  Bangalore   9717479341
#
#                               email       platform vehicle_type  \
# 20494        vijay.pandey@yahoo.com             Na        Sedan
# 34608        mukesh.verma@yahoo.com            Ola         Bike
# ...

# %%
df['age'] = df['age'].fillna('70')

# %%
## This code fills the age column where NaN values exist with random values between 1 and 100

import numpy as np

mask = df['age'].isna()

df.loc[mask, 'age'] = np.random.randint(
    1, 101, size=mask.sum()
)
df.sample(1000)
# Out:
#        driver_id        driver_name  age       city        phone  \
# 25891  DRV315181      Sanjay Tiwari   21  Bangalore   9258550022
# 49256  DRV183852      Rakesh Tiwari   42       Pune   9148866426
# 23995  DRV263574     Hitesh Verma     51  Bangalore      9439802
# 31667  DRV577074     Rajesh Chauhan   51    Kolkata   9961068107
# 12575  DRV116985       Ajay Chauhan   44     Jaipur   9494716045
# ...          ...                ...  ...        ...          ...
# 33873  DRV789209   pradeep tripathi   31    Lucknow   9912984439
# 36578  DRV889908         Deepak Jha   47      Delhi  91578843362
# 28144  DRV287728       Sunil Shukla   47    Chennai   9746415157
# 41231  DRV265290  pradeep chaudhary   50    Lucknow  91040403040
# 33406  DRV001071         Mukesh Rao   70     Jaipur   9697702370
#
#                                    email       platform vehicle_type  \
# 25891           sanjay.tiwarihotmail.com          Uber          Auto
# ...

# %%
df['age'] = df['age'].astype('string')
print(df['age'].dtype)
# Out:
# string

# %%
df['age'] = df['age'].str.lstrip('-')
df['age'] = df['age'].str.lstrip('yrs')
df['age'] = df['age'].replace({'unknown' :'70'})

# %%
df["age"] = df["age"].str.replace("yrs", "", regex=False).str.strip().astype(int)

# %%
df['age'].unique()
# Out:
# array([ 70,  45,  53,  46,  25,  32,  21, 999,  43,  39,  26,  37,  30,
#         42,  34,  44,  47,  54,  41,  50,  36,  49,  40,  27,  52,  55,
#         28,  29,  22,  51,  23,  33,  35,  48,  24,  20,  31,  38])

# %%
## This is to remove the negative values and also the yrs in the age column.
df['driving_test_score_10'] = df['driving_test_score_10'].astype("string")
df['driving_test_score_10'] = df['driving_test_score_10'].str.lstrip('-')
#df['age'] = df['age'].str.rstrip('yrs')
df.sample(1000)
# Out:
#        driver_id       driver_name  age       city        phone  \
# 9836   DRV784532    Umesh Tripathi   43    Lucknow   9110357977
# 1833   DRV878091      naveen patel   47  Bangalore   9244888954
# 40871  DRV728657     MAHESH MISHRA   32      Delhi   9323485648
# 44677  DRV841765    Yogesh Singh    999     Mumbai  91083456001
# 22429  DRV574790        Girish Jha   36    Kolkata   9673456516
# ...          ...               ...  ...        ...          ...
# 37091  DRV417264        Anil Verma   70     Mumbai   9287905601
# 1301   DRV252206         Vijay Rao   32  Bangalore   9235110466
# 3351   DRV592341      Vikram Dubey   32    Lucknow   9844064425
# 19251  DRV947986  Ganesh Chaudhary   37      Delhi   9022484102
# 49755  DRV499903      Bharat Kumar  999     Jaipur   9723684956
#
#                               email platform vehicle_type vehicle_condition  \
# 9836       umesh.tripathi@yahoo.com      Ola        Sedan              Poor
# ...

# %%
## This is to capitalise the platform column to give it a uniform format and also convert the data type from object to string.

df['platform'] = df['platform'].str.capitalize()
df['platform'] = df['platform'].astype("string")
print(df['platform'].dtype)
# Out:
# string

# %%
df['platform'] = df['platform'].fillna('Bolt')

# %%
df['customer_handling_score_10'] = df['customer_handling_score_10'].replace({
   #'NaN': '70',
   # 'Mini ': 'Trailer',
    #'unknown': '80',
    #'999' : '90',
    #'Unknown': 'Experienced',
    #'None': 'Fairly_Experienced',
    #'Avg': 'Average',
    #'poor': 'Super',
    #'Unknown': 'Motorcycle',
    #'Na': '1-20 yrs',
    #'-': '10-30 yrs',
    #"<NA>": 'Bus',
    #'Auto': '',
    #'suv' : 'SUV'
    #'uber': '',
    '<NA>': '6'
})
df.sample(10000)
# Out:
#        driver_id        driver_name  age       city        phone  \
# 17476  DRV674523     Yogesh Chauhan   70    Kolkata  91260815809
# 22197  DRV096955       harish yadav   53    Kolkata   9080107499
# 16179  DRV091162   Sunil Srivastava   46      Delhi      9447406
# 49749  DRV217897        Umesh Yadav   23    Kolkata   9743574010
# 38110  DRV775348      Rajesh Shukla   27  Hyderabad  91873779827
# ...          ...                ...  ...        ...          ...
# 21451  DRV743682  Naresh Srivastava   31     Mumbai  91354410007
# 4193   DRV345745      Mukesh Tiwari   53  Ahmedabad   9143052392
# 25871  DRV536340     Naresh Chauhan   33     Mumbai   9401258367
# 48992  DRV190247         Naveen Jha   29       Pune   9995080733
# 22554  DRV154989         Amit Gupta   33  Ahmedabad  91315862080
#
#                                   email       platform vehicle_type  \
# 17476          yogesh.chauhan@yahoo.com           Uber          Suv
# ...

# %%
## This capitalises the city column to give it a uniform format and also converts the data type from object to string.
df['city'] = df['city'].str.capitalize()
df['city'] = df['city'].astype("string")
df.sample(1000)
# Out:
#        driver_id      driver_name  age       city        phone  \
# 9523   DRV467874    Harish Shukla   53     Jaipur   9309807047
# 28955  DRV908846    Dinesh Shukla   29      Delhi  91619675657
# 38806  DRV499070       Ravi Patel   43       Pune   9758757051
# 13815  DRV674745        ravi nair   20     Jaipur  91246836032
# 11732  DRV564603       Vikram Jha   39  Ahmedabad   9055270416
# ...          ...              ...  ...        ...          ...
# 14007  DRV982971    Santosh Jha     43  Hyderabad  91515249046
# 2613   DRV849280   Lokesh Chauhan   31     Mumbai  91660549486
# 1534   DRV919755     Rakesh Yadav   34    Lucknow   9485751633
# 30938  DRV574374     Bharat Gupta   50     Jaipur      9889472
# 25776  DRV710922      RAVI PANDEY   53    Lucknow  91970779531
#
#                               email       platform vehicle_type  \
# 9523   harish.shukla@rediffmail.com  Uber & rapido         Auto
# 28955  dinesh.shukla@rediffmail.com            Ola         Bike
# ...

# %%
df['route_knowledge_score_10'].unique()
# Out:
# array([ 5.8,  7.5,  9. ,  9.6,  6.5,  8.6,  8.7,  6.4,  7.9,  7.7,  3.6,
#         5.2,  6.8,  8.5,  7.1,  4.6,  1.2,  5. ,  3.2,  3.5,  3.8,  5.6,
#         4.9,  8.8, 10. ,  6.7,  6.3,  9.9,  3.4,  9.8,  0.3,  9.4,  4.2,
#         6.2,  3.9,  6. ,  9.5,  7.4,  3. ,  7. ,  6.1,  3.3,  8. ,  4. ,
#         4.7,  4.5,  7.6,  5.9,  1.3,  4.1,  5.1,  4.3,  8.1,  5.4,  0.9,
#         5.5,  6.6,  3.7,  9.3,  8.2,  5.3,  9.2,  3.1,  7.8,  7.2,  9.1,
#         4.8,  6.9,  9.7,  8.9,  4.4,  7.3,  0.4,  8.4,  1.5,  5.7,  1.1,
#         1.4,  8.3,  0.7,  0.8,  1.9,  2. ,  0.2,  1.8,  1. ,  0.5,  1.7,
#         1.6,  0.1,  0.6])

# %%
## This converts the data type from object to string.
df['route_knowledge_score_10'] = df['route_knowledge_score_10'].astype("string")
print(df['route_knowledge_score_10'].dtype)
# Out:
# string

# %%
## This is to remove the negative values and also the yrs in the age column.
df['route_knowledge_score_10'] = df['route_knowledge_score_10'].str.lstrip('-')
df.sample(1000)
# Out:
#        driver_id        driver_name  age       city        phone  \
# 6778   DRV353935         Ravi Verma   26    Kolkata   9727842290
# 18757  DRV018025       Lokesh Kumar   55       Pune   9087596412
# 29063  DRV196568      Bharat Pandey   27    Lucknow   9997340950
# 48259  DRV946956       Dinesh Reddy  999  Ahmedabad   9650830476
# 22719  DRV431871        Ramesh Nair   27     Jaipur   9549681689
# ...          ...                ...  ...        ...          ...
# 36312  DRV108755       Ganesh Kumar   27     Mumbai   9716441411
# 9867   DRV457380       Girish Patel   70  Hyderabad  91170545290
# 4341   DRV704704  Girish Srivastava   49    Kolkata   9329134288
# 48427  DRV825806       Naveen Dubey   42    Kolkata   9190774511
# 26339  DRV738304         Ravi Kumar   48    Kolkata   9652150999
#
#                              email platform vehicle_type vehicle_condition  \
# 6778     ravi.verma@rediffmail.com     Uber         Auto             Super
# ...

# %%
df['route_knowledge_score_10'] = df['route_knowledge_score_10'].fillna('7.5')

# %%
## This code fills the age column where NaN values exist with random values between 0 and 10

import numpy as np

mask = df['customer_handling_score_10'] == 6

df.loc[mask, 'customer_handling_score_10'] = np.random.randint(
    0, 10, size=mask.sum()
)
df.sample(1000)
# Out:
#        driver_id     driver_name  age       city        phone  \
# 7251   DRV594129     Mukesh Nair   31    Chennai   9034173920
# 4046   DRV053959  Pradeep Sharma   31    Kolkata   9811224087
# 6971   DRV449136     Amit Shukla   33  Ahmedabad   9169416303
# 48461  DRV930830    Vikram Dubey   43  Ahmedabad   9822328115
# 49620  DRV993931    Girish Dubey   45      Delhi   9931483953
# ...          ...             ...  ...        ...          ...
# 9113   DRV925971   Santosh Gupta   23       Pune  91794289155
# 48200  DRV403168   Sunil Chauhan   36     Jaipur   9429740927
# 43969  DRV287082   Dinesh Shukla   20  Ahmedabad  91890501749
# 21475  DRV425609   Naresh Mishra   49     Mumbai   9845521142
# 23428  DRV987643   Rakesh Tiwari   35  Hyderabad   9724433361
#
#                                email       platform vehicle_type  \
# 7251      mukesh.nair@rediffmail.com  Uber & rapido          Suv
# 4046   pradeep.sharma@rediffmail.com           Uber        Sedan
# ...

# %%
df['vehicle_type'].unique()
# Out:
# array(['Auto', 'Mini ', 'Suv', 'Mini', 'Bike', 'Sedan', 'Tricycle',
#        'Motorbike', 'Bicycle', 'Catapiller', 'Truck'], dtype=object)

# %%
## This converts the data type from object to string.
df['vehicle_type'] = df['vehicle_type'].astype("string")
print(df['vehicle_type'].dtype)
# Out:
# string

# %%
df['vehicle_type'] = df['vehicle_type'].str.capitalize()
df['vehicle_type'] = df['vehicle_type'].fillna('Motorbike')
df['vehicle_type'] = df['vehicle_type'].replace({
   #'NaN': '70',
   # 'Mini ': 'Trailer',
    #'unknown': '80',
    #'999' : '90',
    #'Unknown': 'Experienced',
    'None': 'Bicycle',
    #'Avg': 'Average',
    #'poor': 'Super',
    'Unknown': 'Tricycle',
    'Na': 'Catapiller',
    '-': 'Truck',
    #"<NA>": 'Bus',
    #'Auto': '',
    #'suv' : 'SUV'
    #'uber': '',
    #'<NA>': '6'
})
df.sample(10000)
# Out:
#        driver_id        driver_name  age       city        phone  \
# 22897  DRV073991    Sanjay Pandey     33       Pune   9269374405
# 40529  DRV898434      Bharat Tiwari   24  Bangalore   9874922087
# 28349  DRV796780    Naveen Tripathi   38     Jaipur      9838351
# 9225   DRV299124        Rakesh Nair   49    Chennai   9567373320
# 13340  DRV127564       Girish Yadav   28    Kolkata   9062379965
# ...          ...                ...  ...        ...          ...
# 38796  DRV481542           Ravi Jha   32    Kolkata  91223341098
# 25211  DRV233705         Ravi Verma   27      Delhi  91856766877
# 49400  DRV237087  Rajesh Srivastava   35    Chennai   9691735305
# 36496  DRV233731        Sunil Verma   47    Lucknow  91058647660
# 38784  DRV094677       Lokesh Kumar   46       Pune   9204009136
#
#                                   email platform vehicle_type  \
# 22897           sanjay.pandey@gmail.com   Rapido         Auto
# ...

# %%
df['vehicle_condition'].unique()
# Out:
# array(['Good', 'Excellent', 'Average', 'Super', 'Poor', 'Great',
#        'Wonderful', 'Fair', 'Beautiful'], dtype=object)

# %%
## This converts the data type from object to string.
df['vehicle_condition'] = df['vehicle_condition'].astype("string")
print(df['vehicle_condition'].dtype)
# Out:
# string

# %%
df['vehicle_condition'] = df['vehicle_condition'].str.capitalize()
df['vehicle_condition'] = df['vehicle_condition'].fillna('Super')
df['vehicle_condition'] = df['vehicle_condition'].replace({
   #'NaN': '70',
   # 'Mini ': 'Trailer',
    #'unknown': '80',
    #'999' : '90',
    'Unknown': 'Great',
    'None': 'Beautiful',
    'Avg': 'Average',
    #'poor': 'Super',
    #'Unknown': 'Tricycle',
    'Na': 'Fair',
    '-': 'Wonderful',
    #"<NA>": 'Bus',
    #'Auto': '',
    #'suv' : 'SUV'
    #'uber': '',
    #'<NA>': '6'
})
df.sample(10000)
# Out:
#        driver_id        driver_name  age       city       phone  \
# 1636   DRV912330        Vijay Jha     46    Lucknow  9229358106
# 22997  DRV641111         Yogesh Jha   22    Lucknow  9840214344
# 39208  DRV828982       Harish Verma   35     Mumbai  9581683039
# 23586  DRV220681  Mahesh Srivastava   36       Pune  9807781148
# 30141  DRV324053     Harish Chauhan   53  Hyderabad  9041975200
# ...          ...                ...  ...        ...         ...
# 29181  DRV128707      Sanjay Mishra   22       Pune  9622929043
# 14786  DRV999969      Deepak Tiwari   51  Ahmedabad  9630168496
# 30372  DRV370434       Sanjay Singh  999       Pune  9519663678
# 33668  DRV419545     Mahesh Dubey     32    Chennai  9887686517
# 4142   DRV209607    Naresh Tripathi   52     Mumbai  9607955034
#
#                                   email       platform vehicle_type  \
# 1636           vijay.jha@rediffmail.com           Uber         Mini
# ...

# %%
df['experience_level'].unique()
# Out:
# array(['4+ yrs', 'Fresher', '1-3 yrs', '5+ yrs', '3-5 yrs', 'High',
#        '7+ yrs', '6 yrs', '8 yrs', '8+ yrs'], dtype=object)

# %%
## This converts the data type from object to string.
df['experience_level'] = df['experience_level'].astype("string")
print(df['experience_level'].dtype)
# Out:
# string

# %%
df['experience_level'] = df['experience_level'].str.capitalize()
df['experience_level'] = df['experience_level'].fillna('High')
df['experience_level'] = df['experience_level'].replace({
   #'NaN': '70',
   # 'Mini ': 'Trailer',
    #'unknown': '80',
    #'999' : '90',
    '0-1 yr' : '4+ yrs',
    'Unknown': '7+ yrs',
    'None': '8+ yrs',
    #'Avg': 'Average',
    #'poor': 'Super',
    #'Unknown': 'Tricycle',
    'Na': '6 yrs',
    '-': '8 yrs',
    #"<NA>": 'Bus',
    #'Auto': '',
    #'suv' : 'SUV'
    #'uber': '',
    #'<NA>': '6'
})
df.sample(10000)
# Out:
#        driver_id       driver_name  age       city        phone  \
# 48385  DRV893614      Sunil Pandey   45  Hyderabad   9148369932
# 12192  DRV433465     DEEPAK SHUKLA   40      Delhi   9008530751
# 45446  DRV415302      Suresh Verma   34    Chennai   9422315593
# 18646  DRV946722     HITESH MISHRA   70    Chennai   9562963220
# 36405  DRV936644        Vikram Rao   35    Lucknow   9163745687
# ...          ...               ...  ...        ...          ...
# 11950  DRV640318     Dinesh Sharma   44     Jaipur      9701776
# 26697  DRV580832      Yogesh Kum@r   54  Hyderabad   9142362518
# 33431  DRV726409  Dinesh Chaudhary   26    Chennai   9102906449
# 1900   DRV511051     Lokesh Pandey   28  Hyderabad  91067686128
# 10924  DRV771523      Umesh Shukla   45     Jaipur  91510664901
#
#                                  email       platform vehicle_type  \
# 48385      sunil.pandey@rediffmail.com          Uber           Suv
# ...

# %%
df['driving_test_score_10'].unique()
# Out:
# <StringArray>
# [ '4.3',  '9.3',  '6.3',  '8.7', '10.0',  '8.8',  '8.1',  '1.1',  '7.5',
#   '7.4',  '0.6',  '7.7',  '6.2',  '4.8',  '7.1',  '0.9',  '5.5',  '8.9',
#   '6.4',  '5.1',  '7.0',  '7.6',  '5.7',  '9.1',  '8.3',  '4.6',  '4.0',
#   '7.2',  '8.0',  '9.7',  '4.2',  '9.5',  '4.9',  '5.8',  '5.0',  '6.9',
#   '4.1',  '6.5',  '4.5',  '9.8',  '5.4',  '4.4',  '1.3',  '9.2',  '4.7',
#   '7.3',  '1.5',  '8.6',  '8.4',  '1.7',  '5.3',  '6.1',  '6.0',  '9.6',
#   '7.9',  '6.8',  '5.2',  '5.6',  '0.7',  '9.4',  '9.9',  '7.8',  '8.2',
#   '6.6',  '6.7',  '9.0',  '5.9',  '8.5',  '1.0',  '0.8',  '0.4',  '0.5',
#   '0.3',  '1.8',  '1.2',  '0.2',  '1.4',  '1.6',  '1.9',  '0.1',  '2.0']
# Length: 81, dtype: string

# %%
## This converts the data type from object to string.
df['driving_test_score_10'] = df['driving_test_score_10'].astype("string")
print(df['driving_test_score_10'].dtype)
# Out:
# string

# %%
df['driving_test_score_10'] = df['driving_test_score_10'].fillna('7.5')

# %%
df['route_knowledge_score_10'].unique()
# Out:
# <StringArray>
# [ '5.8',  '7.5',  '9.0',  '9.6',  '6.5',  '8.6',  '8.7',  '6.4',  '7.9',
#   '7.7',  '3.6',  '5.2',  '6.8',  '8.5',  '7.1',  '4.6',  '1.2',  '5.0',
#   '3.2',  '3.5',  '3.8',  '5.6',  '4.9',  '8.8', '10.0',  '6.7',  '6.3',
#   '9.9',  '3.4',  '9.8',  '0.3',  '9.4',  '4.2',  '6.2',  '3.9',  '6.0',
#   '9.5',  '7.4',  '3.0',  '7.0',  '6.1',  '3.3',  '8.0',  '4.0',  '4.7',
#   '4.5',  '7.6',  '5.9',  '1.3',  '4.1',  '5.1',  '4.3',  '8.1',  '5.4',
#   '0.9',  '5.5',  '6.6',  '3.7',  '9.3',  '8.2',  '5.3',  '9.2',  '3.1',
#   '7.8',  '7.2',  '9.1',  '4.8',  '6.9',  '9.7',  '8.9',  '4.4',  '7.3',
#   '0.4',  '8.4',  '1.5',  '5.7',  '1.1',  '1.4',  '8.3',  '0.7',  '0.8',
#   '1.9',  '2.0',  '0.2',  '1.8',  '1.0',  '0.5',  '1.7',  '1.6',  '0.1',
#   '0.6']
# Length: 91, dtype: string

# %%
df['customer_handling_score_10'].unique()
# Out:
# array([ 7.7,  9. ,  5.5,  5.3,  7.9, 10. ,  9.7,  8.5,  5.9,  6.2,  4.9,
#         6.7,  6.9,  6.8,  1. ,  3.5,  5. ,  4.1,  8.9,  7.6,  6.5,  3.6,
#         4.3,  3.8,  3.2,  7.5,  4.6,  5.7,  3.7,  0.9,  4.7,  4.2,  1.6,
#         8.8,  0.6,  6.4,  6.3,  9.8,  7. ,  9.5,  8.3,  3.1,  9.4,  6.6,
#         9.1,  7.3,  7.4,  8.6,  9.6,  7.2,  3. ,  3.3,  8.1,  3.4,  4.4,
#         4. ,  8.4,  8. ,  5.1,  5.2,  1.9,  5.4,  4.5,  6.1,  7.1,  5.6,
#         1.3,  1.2,  8.7,  3.9,  9.2,  1.8,  7.8,  9.9,  9.3,  8.2,  1.7,
#         2. ,  5.8,  0.2,  0.7,  4.8,  1.5,  1.1,  0.8,  0.3,  0.4,  0.5,
#         0.1,  1.4,  0. ])

# %%
## This converts the data type from object to string.
df['customer_handling_score_10'] = df['customer_handling_score_10'].astype("string")
print(df['customer_handling_score_10'].dtype)
# Out:
# string

# %%
df['customer_handling_score_10'] = df['customer_handling_score_10'].fillna('8.5')
df['customer_handling_score_10'] = df['customer_handling_score_10'].str.lstrip('-')

# %%
df['overall_interview_score_10'].unique()
# Out:
# array([ 5.3,  8.1,  6.9,  7.8,  6. ,  1.4,  8.2,  8.3,  6.7,  5.8,  7.7,
#         8.8,  7.6,  6.5,  7.5,  4.1,  6.2,  1.6,  6.4,  7.2,  7.4,  3.6,
#         6.3,  6.1,  5.2,  1.3,  5.6,  5.7,  5. ,  5.5,  6.8,  6.6, 10. ,
#         7.3,  4.2,  7.1,  1. ,  7. ,  4.8,  4.9,  5.1,  4.5,  5.9,  8. ,
#         4.6,  5.4,  7.9,  2. ,  9.7,  1.8,  1.9,  8.6,  1.5,  8.4,  9.2,
#         8.5,  4.7,  4.4,  1.7,  0.8,  0.7,  0.3,  8.7,  9.1,  4.3,  0.4,
#         0.2,  8.9,  1.2,  0.6,  4. ,  1.1,  0.5,  9. ,  9.4,  3.9,  0.9,
#         3.8,  0.1,  9.3,  9.6,  3.7,  9.5,  3.5,  9.8,  3.4])

# %%
## This converts the data type from object to string.
df['overall_interview_score_10'] = df['overall_interview_score_10'].astype("string")
print(df['overall_interview_score_10'].dtype)
# Out:
# string

# %%
df['overall_interview_score_10'] = df['overall_interview_score_10'].fillna('8.8')
df['overall_interview_score_10'] = df['overall_interview_score_10'].str.lstrip('-')
df.sample(1000)
# Out:
#        driver_id      driver_name  age       city        phone  \
# 28818  DRV581812     N@veen Reddy   55    Chennai   9584373466
# 12757  DRV902538      Anil Shukla   45  Ahmedabad   9719874090
# 42087  DRV881421    Pradeep Patel   50    Kolkata   9335266547
# 16154  DRV760025    Lokesh Pandey   24  Bangalroe   9686193305
# 14883  DRV820227      Santosh Jha   29  Hyderabad      9652576
# ...          ...              ...  ...        ...          ...
# 18918  DRV368669   Pradeep Sharma   25    Kolkata   9800197016
# 23687  DRV867581     manoj sharma   53    Kolkata  91074369527
# 22573  DRV067649     Ramesh Gupta   28    Kolkata   9787328314
# 3784   DRV483157    Santosh Jha     54       Pune   9604399359
# 23588  DRV389045  Umesh Chaudhary   48    Kolkata   9480297433
#
#                                email       platform vehicle_type  \
# 28818         naveen.reddy@yahoo.com           Bolt        Sedan
# 12757          Anil Shukla@gmail.com          Uber          Auto
# ...

# %%
df['document_verification'].unique()
# Out:
# array(['Fail', 'Distinction', 'Average', 'Pass', 'Pending', 'Credit',
#        'Exceptional', 'Fair'], dtype=object)

# %%
## This converts the data type from object to string.
df['document_verification'] = df['document_verification'].astype("string")
print(df['document_verification'].dtype)
# Out:
# string

# %%
df['document_verification'] = df['document_verification'].str.capitalize()
df['document_verification'] = df['document_verification'].fillna('Distinction')
df['document_verification'] = df['document_verification'].replace({
   #'NaN': '70',
   # 'Mini ': 'Trailer',
    #'unknown': '80',
    #'999': '90',
    #'0-1 yr' : '4+ yrs',
    #'Unknown':'High',
    'None':'Credit',    
    #'Avg': 'Average',
    #'poor': 'Super',
    'Unknown':'Average',
    'Na': 'Fair',
    '-': 'Exceptional',
    #"<NA>": 'Bus',
    #'Auto': '',
    #'suv' : 'SUV'
    #'uber': '',
    #'<NA>': '6'
})
df.sample(10000)
# Out:
#        driver_id        driver_name  age       city        phone  \
# 41545  DRV954284      Dinesh Pandey   30    Lucknow   9178229710
# 40031  DRV790730     Harish Chauhan   30  Bangalore   9383303394
# 25228  DRV266834        Sunil Singh   20     Jaipur  91308631286
# 33291  DRV687279      Ramesh Tiwari   55  Bangalroe  91992197740
# 21732  DRV012734  Naresh Srivastava   27  Ahmedabad  91461333062
# ...          ...                ...  ...        ...          ...
# 8653   DRV029054       Manoj Sharma   44       Pune   9831335943
# 22402  DRV400348         Sunil Nair   43      Delhi  91442975856
# 16404  DRV844676           ravi rao  999  Ahmedabad  91649861521
# 10944  DRV255549      HARISH PANDEY   70  Bangalore   9778638417
# 28466  DRV536811    Naveen Tripathi   38  Ahmedabad   9434583120
#
#                                    email       platform vehicle_type  \
# 41545          dinesh.pandey@hotmail.com        Rapido         Sedan
# ...

# %%
df['document_verification'].unique()
# Out:
# <StringArray>
# [       'Fail', 'Distinction',     'Average',        'Pass',     'Pending',
#       'Credit', 'Exceptional',        'Fair']
# Length: 8, dtype: string

# %%
df['background_check_status'].unique()
# Out:
# array(['Clear', 'Pending', 'Flagged'], dtype=object)

# %%
## This converts the data type from object to string.
df['background_check_status'] = df['background_check_status'].astype("string")
print(df['background_check_status'].dtype)
# Out:
# string

# %%
df['background_check_status'] = df['background_check_status'].str.capitalize()
df['background_check_status'] = df['background_check_status'].fillna('Clear')
df['background_check_status'] = df['background_check_status'].replace({
'Na': 'Clear', 
'Unknown': 'Clear', 
'None': 'Pending', 
'-': 'Clear'
})
df.sample(1000)
# Out:
#        driver_id      driver_name  age       city        phone  \
# 44604  DRV566024      Girish N@ir   20      Delhi   9018461117
# 45080  DRV950181       Anil Verma   45      Delhi   9062096708
# 47416  DRV350815     Dinesh Gupta   30     Mumbai   9759742829
# 5374   DRV948743      Umesh Singh   51    Kolkata   9538731603
# 12528  DRV683981    Hitesh Sharma   27       Pune   9130163608
# ...          ...              ...  ...        ...          ...
# 1384   DRV843938    Rajesh Mishra   45  Ahmedabad  91805711857
# 7434   DRV694211  Pr@deep Ch@uh@n   23  Ahmedabad      9279325
# 32785  DRV902186    Vijay Kumar     53    Kolkata  91583516670
# 25097  DRV604009       AJAY KUMAR   38    Chennai  91412550312
# 4059   DRV930384      Manoj Kumar   54       Pune   9627792846
#
#                               email platform vehicle_type vehicle_condition  \
# 44604         Girish N@ir@gmail.com   Rapido         Auto             Super
# ...

# %%
df['background_check_status'].unique()
# Out:
# <StringArray>
# ['Clear', 'Pending', 'Flagged']
# Length: 3, dtype: string

# %%
df['interview_result'].unique()
# Out:
# array(['On hold', 'Selected', 'Rejected', 'Waitlist', 'Pending'],
#       dtype=object)

# %%
## This converts the data type from object to string.
df['interview_result'] = df['interview_result'].astype("string")
print(df['interview_result'].dtype)
# Out:
# string

# %%
df['interview_result'] = df['interview_result'].str.capitalize()
df['interview_result'] = df['interview_result'].fillna('Selected')
df['interview_result'] = df['interview_result'].replace({
'Na': 'Selected', 
'Unknown': 'Selected', 
'None': 'Pending', 
'-': 'Pending'
})
df.sample(1000)
# Out:
#        driver_id        driver_name  age       city        phone  \
# 31420  DRV117141       Naveen Kumar   70  Bangalore   9113454480
# 18164  DRV867812         Ravi Dubey   34     Mumbai   9673845464
# 18336  DRV272819       Girish Verma   29  Hyderabad   9301277243
# 39894  DRV935806       Deepak Singh   51     Jaipur   9690905061
# 43809  DRV101160    Pradeep Chauhan   27  Hyderabad   9425238777
# ...          ...                ...  ...        ...          ...
# 10973  DRV833235  Bharat Srivastava   70    Chennai  91094027612
# 3336   DRV658415      Girish Mishra   29    Kolkata   9389005899
# 5550   DRV351990   Pradeep Tripathi   21    Kolkata   9932822615
# 47527  DRV814271          Manoj Jha   37       Pune   9202473365
# 41754  DRV794596       Vikram Reddy   32  Hyderabad   9783133862
#
#                                email       platform vehicle_type  \
# 31420    naveen.kumar@rediffmail.com        Rapido          Auto
# ...

# %%
df['interview_result'].unique()
# Out:
# <StringArray>
# ['On hold', 'Selected', 'Rejected', 'Waitlist', 'Pending']
# Length: 5, dtype: string

# %%
df['rejection_reason'].unique()
# Out:
# array(['Invalid_id', 'Low rating history', 'Not applicable',
#        'Poor communication', 'Incomplete documents',
#        'Vehicle age too old', 'Background check failed',
#        'Failed driving test', 'Selected'], dtype=object)

# %%
## This converts the data type from object to string.
df['rejection_reason'] = df['rejection_reason'].astype("string")
print(df['rejection_reason'].dtype)
# Out:
# string

# %%
df['rejection_reason'] = df['rejection_reason'].str.capitalize()
df['rejection_reason'] = df['rejection_reason'].fillna('Invalid_id')
df['rejection_reason'] = df['rejection_reason'].replace({
'Na': 'Invalid_id', 
'Unknown': 'Selected', 
'None': 'Poor communication', 
'-': 'Background check failed'
})
df.sample(1000)
# Out:
#        driver_id       driver_name  age       city        phone  \
# 26172  DRV611076      Ajay Singh     22    Lucknow   9564091372
# 46313  DRV112831  santosh tripathi   54  Hyderabad  91877316801
# 1906   DRV427791     Naresh Pandey   47      Delhi   9353341642
# 40809  DRV361000     Naveen Pandey   29  Bangalore   9104945692
# 17225  DRV652222      mahesh dubey   36      Delhi   9957927966
# ...          ...               ...  ...        ...          ...
# 869    DRV839443        amit yadav   43  Ahmedabad   9905858392
# 36568  DRV636866        Amit Verma   31       Pune   9483292995
# 43453  DRV781108          Amit Jha   27       Pune   9806052580
# 45679  DRV831946      Ajay Chauhan   29      Delhi  91176502491
# 34559  DRV618458     Dinesh Mishra   29     Jaipur   9792836567
#
#                               email       platform vehicle_type  \
# 26172        ajay.singh@hotmail.com          Uber          Auto
# 46313    santosh.tripathi@gmail.com         Rapido        Sedan
# ...

# %%
df['rejection_reason'].unique()
# Out:
# <StringArray>
# [             'Invalid_id',      'Low rating history',
#           'Not applicable',      'Poor communication',
#     'Incomplete documents',     'Vehicle age too old',
#  'Background check failed',     'Failed driving test',
#                 'Selected']
# Length: 9, dtype: string

# %%
df['onboarding_date'].unique()
# Out:
# array(['2025-02-10 22:07:31', '2026-01-12 11:59:18',
#        '2021-04-19 00:00:00', ..., '2025-09-26 06:05:30',
#        '2026-04-12 21:14:46', '2025-05-06 04:10:59'], dtype=object)

# %%
## This code generates random date values for the onboarding column. 

import pandas as pd
import numpy as np

df['onboarding_date'] = pd.to_datetime(df['onboarding_date'], errors='coerce')

start = pd.Timestamp("2025-01-01")
end = pd.Timestamp("2026-08-11")

mask = df["onboarding_date"].isna()

df.loc[mask, "onboarding_date"] = pd.to_datetime(
    np.random.randint(
        start.value // 10**9,
        end.value // 10**9,
        size=mask.sum()
    ),
    unit="s"
)
df.sample(1000)
# Out:
#        driver_id    driver_name  age       city        phone  \
# 17462  DRV736940  Manoj Chauhan   20    Chennai   9583153953
# 47774  DRV310404  Lokesh Tiwari   50       Pune   9821571863
# 2634   DRV067302  DINESH TIWARI   37    Kolkata   9118018623
# 8382   DRV652727    Santosh Rao   46  Hyderabad      9648176
# 16365  DRV948845  naveen tiwari   40     Mumbai   9441625063
# ...          ...            ...  ...        ...          ...
# 33474  DRV040094     Ajay Dubey   47  Hyderabad   9805536566
# 9063   DRV498517    Ravi Tiwari   40     Jaipur      9439022
# 36933  DRV328161  VIKRAM SHUKLA   70  Ahmedabad  91237748509
# 49713  DRV322842     Vij@y N@ir   22       Pune   9699638413
# 38360  DRV447136   Harish Singh   37       Pune   9398427677
#
#                             email platform vehicle_type vehicle_condition  \
# 17462    manoj.chauhan@@yahoo.com  Rapido           Suv           Average
# 47774   lokesh.tiwari@hotmail.com   Rapido         Auto             Super
# ...

# %%
df['onboarding_date'].unique()
# Out:
# <DatetimeArray>
# ['2025-02-10 22:07:31', '2026-01-12 11:59:18', '2021-04-19 00:00:00',
#  '2021-05-27 00:00:00', '2026-02-08 13:31:18', '2023-04-01 00:00:00',
#  '2023-08-08 00:00:00', '2022-02-06 00:00:00', '2025-12-30 07:03:08',
#  '2025-07-04 10:48:53',
#  ...
#  '2025-11-25 01:15:51', '2026-01-07 07:46:46', '2026-04-23 02:16:25',
#  '2026-05-06 22:04:05', '2025-06-23 16:04:25', '2025-10-09 23:03:17',
#  '2025-06-21 04:21:16', '2025-09-26 06:05:30', '2026-04-12 21:14:46',
#  '2025-05-06 04:10:59']
# Length: 49969, dtype: datetime64[ns]

# %%
df['is_currently_active'].unique()
# Out:
# array([False,  True])

# %%
## This converts the data type from object to string.
df['is_currently_active'] = df['is_currently_active'].astype("string")
print(df['is_currently_active'].dtype)
# Out:
# string

# %%
df['is_currently_active'] = df['is_currently_active'].str.capitalize()
df['is_currently_active'] = df['is_currently_active'].fillna('True')
df['is_currently_active'] = df['is_currently_active'].replace({
'No':'False', 
'0': 'False', 
'1': 'True', 
'N': 'False',
'Y': 'True',
'Yes': 'True',
})
df.sample(1000)
# Out:
#        driver_id        driver_name  age       city        phone  \
# 18685  DRV387606       R@mesh P@tel   33    Lucknow  91307905042
# 42260  DRV997146       Suresh Kum@r   44  Bangalore   9283884463
# 24930  DRV891303       MAHESH PATEL   55       Pune  91806107734
# 31459  DRV169152      pradeep kumar   35    Lucknow   9415427610
# 34307  DRV338746    Yogesh Shukla     29    Kolkata  91549719799
# ...          ...                ...  ...        ...          ...
# 42560  DRV212552      Rajesh Tiwari   70    Kolkata  91923068475
# 16601  DRV275589        Sunil Singh   41    Chennai   9376550899
# 29421  DRV702540    Anil Srivastava   27  Ahmedabad   9658486048
# 22983  DRV270156        Girish Nair   43       Pune  91033509799
# 26324  DRV058200         Hitesh Rao   39      Delhi   9146880931
#
#                               email       platform vehicle_type  \
# 18685   ramesh.patel@rediffmail.com  Uber & rapido          Suv
# ...

# %%
## This converts the data type from object to string.
df['preferred_shift'] = df['preferred_shift'].astype("string")
print(df['preferred_shift'].dtype)
# Out:
# string

# %%
df['preferred_shift'] = df['preferred_shift'].str.capitalize()
df['preferred_shift'] = df['preferred_shift'].fillna('Afternoon')
df['preferred_shift'] = df['preferred_shift'].replace({
'Na': 'Evening', 
'Unknown': 'Midweek', 
'None': 'Twice_Weekly', 
'-': 'Weekend',
'Night ': 'Morning',
})

# %%
df['preferred_shift'].unique()
# Out:
# <StringArray>
# [       'Night',      'Weekend',    'Afternoon',          'Day',
#          'Both',      'Morning',      'Midweek', 'Twice_weekly',
#       'Evening']
# Length: 9, dtype: string

# %%
df['driver_id'].unique()
# Out:
# array(['DRV993813', 'DRV937048', 'DRV612651', ..., 'DRV207494',
#        'DRV242949', 'DRV049393'], dtype=object)

# %%
## This converts the data type from object to string.
df['driver_id'] = df['driver_id'].astype("string")
print(df['driver_id'].dtype)
# Out:
# string

# %%
import numpy as np

conversion = df['driver_id']= np.nan
print(conversion)
# Out:
# nan

# %%
##This code creates a driver_id for the drivers using their names, where they have no existing emails.

#DRV037476 

import numpy as np

df["driver_id"] = [
    f"DRV{np.random.randint(0, 1000000):06d}"
    for _ in range(len(df))
]
df.sample(10000)
# Out:
#        driver_id    driver_name  age       city        phone  \
# 32408  DRV704801  Ramesh Tiwari   55   Hydrabad   9214031268
# 48578  DRV317680    RAVI SHUKLA   20     Mumbai  91514914272
# 47756  DRV597006     Ganesh Rao   41       Pune   9284217399
# 42618  DRV009370    Vikram Nair   55     Jaipur   9928642565
# 28060  DRV694188   Lokesh Verma   24     Jaipur   9821698736
# ...          ...            ...  ...        ...          ...
# 33057  DRV900877    umesh verma   29  Ahmedabad  91953149520
# 21873  DRV463142   Pankaj Yadav   45  Bangalore  91821269294
# 5185   DRV908920  MAHESH PANDEY   47    Kolkata   9766187879
# 48971  DRV838803   naresh patel   35      Delhi   9783116596
# 29392  DRV541015  Hitesh Tiwari   27  Ahmedabad   9095180341
#
#                               email       platform vehicle_type  \
# 32408       Ramesh Tiwari@gmail.com           Uber          Suv
# 48578       ravi.shukla@hotmail.com            Ola        Sedan
# ...

# %%
df['driver_id'].unique()
# Out:
# array(['DRV628120', 'DRV604728', 'DRV174928', ..., 'DRV562728',
#        'DRV457916', 'DRV648619'], dtype=object)

# %%
## This converts the data type from object to string.
df['reason_for_joining'] = df['reason_for_joining'].astype("string")
print(df['reason_for_joining'].dtype)
# Out:
# string

# %%
df['reason_for_joining'] = df['reason_for_joining'].str.capitalize()
df['reason_for_joining'] = df['reason_for_joining'].fillna('Part_Time')
df['reason_for_joining'] = df['reason_for_joining'].replace({
'Na': 'Internship', 
'Unknown': 'Trainer', 
'None': 'Passion', 
'-': 'Passive_Income',
})

# %%
df['reason_for_joining'].unique()
# Out:
# <StringArray>
# [      'Side hustle',         'Part_time',     'Not disclosed',
#       'Extra income', 'Lost previous job',   'Family pressure',
#            'Passion',     'Full time job',    'Flexible hours',
#            'Trainer',        'Internship',    'Passive_income']
# Length: 12, dtype: string

# %%
## This converts the data type from object to string.
df['languages_known'] = df['languages_known'].astype("string")
print(df['languages_known'].dtype)
# Out:
# string

# %%
df['languages_known'] = df['languages_known'].str.capitalize()
df['languages_known'] = df['languages_known'].fillna('English, Igbo, Yoruba')

# %%
df['languages_known'].unique()
# Out:
# <StringArray>
# [      'Hindi, tamil, telugu',    'Kannada, tamil, marathi',
#       'Tamil, marathi, hindi', 'Gujarati, kannada, marathi',
#               'Hindi, telugu',             'English, tamil',
#     'English, tamil, marathi',                      'Hindi',
#    'Tamil, gujarati, bengali',                    'Marathi',
#  ...
#       'English, hindi, tamil',    'Marathi, hindi, bengali',
#    'Marathi, gujarati, tamil',   'English, gujarati, tamil',
#     'Kannada, hindi, english',   'Gujarati, tamil, marathi',
#    'Marathi, gujarati, hindi',  'Kannada, english, bengali',
#   'Gujarati, bengali, telugu',   'Gujarati, kannada, hindi']
# Length: 404, dtype: string

# %%
## This converts the data type from object to string.
df['overall_driver_rating'] = df['overall_driver_rating'].astype("string")
print(df['overall_driver_rating'].dtype)
# Out:
# string

# %%
df['overall_driver_rating'] = df['overall_driver_rating'].fillna('7.7')
df['overall_driver_rating'] = df['overall_driver_rating'].str.lstrip('-')
df['overall_driver_rating'] = df['overall_driver_rating'].replace({
#'Na': 'Internship', 
#'Unknown': 'Trainer', 
#'None': 'Passion', 
#'-': 'Passive_Income',
'unrated': '6.9',
})

# %%
df['overall_driver_rating'].unique()
# Out:
# <StringArray>
# ['7.7', '5.8', '4.8', '4.4', '3.1', '4.3', '3.9', '3.3', '4.9', '3.6', '4.6',
#  '2.6', '3.2', '6.9', '3.4', '5.6', '3.8', '6.4', '2.9', '5.2', '4.1', '3.5',
#  '5.5', '1.7', '4.5', '4.2', '4.0', '3.0', '1.0', '5.7', '4.7', '2.5', '3.7',
#  '2.7', '2.8', '6.0', '1.2', '1.6', '1.3', '0.6', '5.3', '6.1', '6.2', '5.0',
#  '0.8', '5.9', '0.2', '0.4', '6.5', '5.4', '1.9', '5.1', '1.1', '1.4', '1.5',
#  '0.9', '6.3', '0.5', '0.7', '1.8', '0.3', '2.0', '0.1']
# Length: 63, dtype: string

# %%
## This converts the data type from object to string.
df['total_trips_completed'] = df['total_trips_completed'].astype("string")
print(df['total_trips_completed'].dtype)
# Out:
# string

# %%
#df['total_trips_completed'] = df['total_trips_completed'].fillna('7450')
#df['total_trips_completed'] = df['total_trips_completed'].str.lstrip('-')

import numpy as np

df['total_trips_completed'] = np.random.randint(2000, 7001, size=len(df))

# %%
df['total_trips_completed'].unique()
# Out:
# array([4822, 3474, 6341, ..., 6816, 6716, 5965])

# %%
## This converts the data type from object to string.
df['trip_completion_rate_%'] = df['trip_completion_rate_%'].astype("string")
print(df['trip_completion_rate_%'].dtype)
# Out:
# string

# %%
df['trip_completion_rate_%'].unique()
# Out:
# <StringArray>
# [ '68.4',  '99.8',  '75.8',  '64.4',  '97.6',  '72.8',  '84.6',  '94.8',
#   '74.5',  '63.1',
#  ...
#   '96.0', '100.7',   '1.2',  '90.0', '102.0',  '80.3',  '75.3',  '97.0',
#  '103.0',  '89.3']
# Length: 451, dtype: string

# %%
df['trip_completion_rate_%'] = df['trip_completion_rate_%'].fillna('74.5')
df['trip_completion_rate_%'] = df['trip_completion_rate_%'].str.lstrip('-')

# %%
## This converts the data type from object to string.
df['cancellation_rate_%'] = df['cancellation_rate_%'].astype("string")
print(df['cancellation_rate_%'].dtype)
# Out:
# string

# %%
df['cancellation_rate_%'] = df['cancellation_rate_%'].fillna('44.5')

# %%
df['cancellation_rate_%'].unique()
# Out:
# <StringArray>
# [ '17.5',  '28.5',  '29.3',  '21.7',  '33.2',   '0.1',  '33.4',  '11.4',
#    '2.3',   '3.4',
#  ...
#  '101.3',   '9.1',  '30.9',  '15.3',   '0.2', '100.2',  '27.8',  '16.2',
#   '28.3', '103.0']
# Length: 402, dtype: string

# %%
df['avg_daily_earnings_INR'].unique()
# Out:
# array(['2275', '1164', '2394', ..., '₹488', '642.00', '₹1690'],
#       dtype=object)

# %%
## This converts the data type from object to string.
df['avg_daily_earnings_INR'] = df['avg_daily_earnings_INR'].astype("string")
print(df['avg_daily_earnings_INR'].dtype)
# Out:
# string

# %%
df['avg_daily_earnings_INR'] = df['avg_daily_earnings_INR'].fillna('4445')

# %%
df['total_complaints'].unique()
# Out:
# array([3.6000e+01, 1.8000e+01, 1.7000e+01, 2.4000e+01, 1.6000e+01,
#        1.4000e+01, 4.4000e+01, 2.1000e+01, 9.9999e+04, 2.3000e+01,
#        9.0000e+00, 3.5000e+01, 3.0000e+01, 4.8000e+01, 3.1000e+01,
#        5.0500e+01, 2.9000e+01, 1.5000e+01, 1.9000e+01, 4.5000e+01,
#        2.6000e+01, 4.1000e+01, 4.9000e+01, 1.0000e+01, 2.2000e+01,
#        2.8000e+01, 3.0000e+00, 4.0000e+01, 3.8000e+01, 1.3000e+01,
#        2.7000e+01, 2.5000e+01, 1.2000e+01, 2.0000e+00, 6.0000e+00,
#        8.0000e+00, 4.3000e+01, 3.4000e+01, 3.3000e+01, 5.0000e+00,
#        1.0000e+00, 3.9000e+01, 7.0000e+00, 3.2000e+01, 5.0000e+01,
#        3.7000e+01, 4.7000e+01, 4.6000e+01, 1.1000e+01, 4.2000e+01,
#        0.0000e+00, 2.0000e+01, 4.0000e+00])

# %%
## This converts the data type from object to string.
df['total_complaints'] = df['total_complaints'].astype("string")
print(df['total_complaints'].dtype)
# Out:
# string

# %%
df['total_complaints'] = df['total_complaints'].fillna('50.5')

# %%
df['total_compliments'].unique()
# Out:
# array([7.7000e+01, 2.2000e+01, 5.9000e+01, 3.0000e+00, 2.0500e+01,
#        1.9000e+01, 6.8000e+01, 7.5000e+01, 2.3000e+01, 1.0000e+00,
#        1.7000e+01, 9.0000e+01, 2.5000e+01, 6.1000e+01, 3.5000e+01,
#        7.0000e+00, 9.9999e+04, 9.1000e+01, 5.4000e+01, 5.5000e+01,
#        4.0000e+01, 8.9000e+01, 4.4000e+01, 9.8000e+01, 3.9000e+01,
#        1.3000e+01, 9.0000e+00, 9.3000e+01, 6.0000e+01, 9.9000e+01,
#        6.9000e+01, 4.2000e+01, 1.0000e+02, 7.9000e+01, 8.0000e+01,
#        2.9000e+01, 4.9000e+01, 8.4000e+01, 4.8000e+01, 7.0000e+01,
#        1.5000e+01, 6.2000e+01, 1.4000e+01, 9.6000e+01, 2.6000e+01,
#        2.4000e+01, 5.2000e+01, 4.1000e+01, 8.3000e+01, 8.8000e+01,
#        4.7000e+01, 3.1000e+01, 1.0000e+01, 3.0000e+01, 2.1000e+01,
#        6.4000e+01, 5.0000e+01, 5.8000e+01, 3.6000e+01, 6.0000e+00,
#        7.8000e+01, 1.1000e+01, 9.2000e+01, 7.4000e+01, 8.1000e+01,
#        5.7000e+01, 7.6000e+01, 8.6000e+01, 3.2000e+01, 4.5000e+01,
# ...

# %%
## This converts the data type from object to string.
df['total_compliments'] = df['total_compliments'].astype("string")
print(df['total_compliments'].dtype)
# Out:
# string

# %%
df['total_compliments'] = df['total_compliments'].fillna('20.5')

# %%
df['interview_date'].unique()
# Out:
# array(['2023-07-10 00:00:00', '2021-11-17 13:17:04',
#        '2021-10-02 04:17:25', ..., '2021-10-29 21:46:09',
#        '2022-09-19 10:09:14', '2024-05-14 20:06:12'], dtype=object)

# %%
## This converts the data type from object to string.
df['interview_date'] = df['interview_date'].astype("string")
print(df['interview_date'].dtype)
# Out:
# string

# %%
df['interview_date'] = df['interview_date'].fillna('20 May 25')

# %%
## This code generates random date values for the onboarding column. 

import pandas as pd
import numpy as np

df['interview_date'] = pd.to_datetime(df['interview_date'], errors='coerce')

start = pd.Timestamp("2021-01-01")
end = pd.Timestamp("2024-08-11")

mask = df["interview_date"].isna()

df.loc[mask, "interview_date"] = pd.to_datetime(
    np.random.randint(
        start.value // 10**9,
        end.value // 10**9,
        size=mask.sum()
    ),
    unit="s"
)
df.sample(1000)
# Out:
#        driver_id     driver_name  age       city       phone  \
# 5206   DRV608937    Yogesh Verma   39     Mumbai  9090598246
# 11193  DRV238678     Umesh Gupta   31  Ahmedabad  9897047937
# 35123  DRV896348   Pradeep Kumar   41  Bangalore  9578229016
# 7060   DRV981221  santosh mishra   38  Hyderabad  9350969097
# 3111   DRV025367     Pankaj Nair   20    Kolkata  9737672540
# ...          ...             ...  ...        ...         ...
# 7758   DRV674153     Amit Sharma   43    Kolkata  9877819928
# 40905  DRV127442    deepak gupta   48       Pune  9359496371
# 49343  DRV659018    Anil Yadav     33     Mumbai  9510863488
# 271    DRV777512   Girish Tiwari   42  Ahmedabad     9015067
# 4300   DRV143647   mahesh mishra   42      Delhi  9321222854
#
#                               email platform vehicle_type vehicle_condition  \
# 5206        yogesh.verma@@gmail.com     Uber    Motorbike             Super
# 11193       umesh.gupta@hotmail.com     Uber        Sedan             Super
# ...

# %%
df['interview_date'].unique()
# Out:
# <DatetimeArray>
# ['2023-07-10 00:00:00', '2021-11-17 13:17:04', '2021-10-02 04:17:25',
#  '2022-08-09 06:34:01', '2023-02-18 16:13:29', '2021-09-21 02:44:35',
#  '2021-07-24 23:29:37', '2022-01-24 00:00:00', '2022-08-19 15:45:18',
#  '2021-03-31 00:00:00',
#  ...
#  '2021-05-19 10:24:51', '2024-01-19 06:16:42', '2024-05-09 23:47:57',
#  '2021-12-13 20:45:58', '2021-01-22 22:48:52', '2022-07-06 13:41:38',
#  '2021-07-11 01:55:51', '2021-10-29 21:46:09', '2022-09-19 10:09:14',
#  '2024-05-14 20:06:12']
# Length: 44822, dtype: datetime64[ns]

# %%
# This converts the data type from object to string.
df['communication_score_10'] = df['communication_score_10'].astype("string")
print(df['communication_score_10'].dtype)
# Out:
# string

# %%
df['communication_score_10'] = df['communication_score_10'].fillna('4.5')
df['communication_score_10'] = df['communication_score_10'].str.lstrip('-')

# %%
df['communication_score_10'].unique()
# Out:
# <StringArray>
# ['10.0',  '7.0',  '4.5',  '7.4',  '4.0',  '8.1',  '4.1',  '7.3',  '7.6',
#   '7.5',  '5.5',  '9.7',  '8.2',  '3.8',  '7.9',  '4.2',  '3.3',  '0.1',
#   '9.3',  '3.2',  '6.0',  '8.7',  '9.5',  '5.0',  '3.1',  '4.4',  '6.6',
#   '6.5',  '6.3',  '8.5',  '3.4',  '7.2',  '7.7',  '9.1',  '4.3',  '5.4',
#   '5.6',  '3.9',  '6.1',  '8.6',  '8.3',  '8.8',  '8.4',  '9.9',  '7.8',
#   '4.7',  '9.6',  '6.8',  '6.4',  '5.9',  '5.7',  '7.1',  '6.2',  '3.5',
#   '3.7',  '3.6',  '4.6',  '9.0',  '6.7',  '1.9',  '5.1',  '5.2',  '8.0',
#   '0.6',  '5.3',  '4.8',  '1.4',  '0.4',  '0.2',  '1.0',  '5.8',  '8.9',
#   '6.9',  '9.8',  '0.8',  '4.9',  '0.7',  '1.3',  '1.1',  '9.2',  '0.9',
#   '1.6',  '1.7',  '1.8',  '3.0',  '9.4',  '1.2',  '1.5',  '0.3',  '2.0',
#   '0.5']
# Length: 91, dtype: string

# %%
df.columns
# Out:
# Index(['driver_id', 'driver_name', 'age', 'city', 'phone', 'email', 'platform',
#        'vehicle_type', 'vehicle_condition', 'experience_level',
#        'preferred_shift', 'reason_for_joining', 'languages_known',
#        'overall_driver_rating', 'total_trips_completed',
#        'trip_completion_rate_%', 'cancellation_rate_%',
#        'avg_daily_earnings_INR', 'total_complaints', 'total_compliments',
#        'peak_hour_availability', 'interview_date', 'communication_score_10',
#        'driving_test_score_10', 'route_knowledge_score_10',
#        'customer_handling_score_10', 'overall_interview_score_10',
#        'document_verification', 'background_check_status', 'interview_result',
#        'rejection_reason', 'onboarding_date', 'is_currently_active'],
#       dtype='object')

# %%
score_columns = [
    'communication_score_10',
    'driving_test_score_10',
    'route_knowledge_score_10',
    'customer_handling_score_10',
    'overall_interview_score_10'
]

df[score_columns] = df[score_columns].apply(
    pd.to_numeric,
    errors='coerce'
)

print(df[score_columns].dtypes)
# Out:
# communication_score_10        Float64
# driving_test_score_10         Float64
# route_knowledge_score_10      Float64
# customer_handling_score_10    Float64
# overall_interview_score_10    Float64
# dtype: object

# %%
df[score_columns].isna().sum()
# Out:
# communication_score_10        0
# driving_test_score_10         0
# route_knowledge_score_10      0
# customer_handling_score_10    0
# overall_interview_score_10    0
# dtype: int64

# %%
df[df['driving_test_score_10'] > 10.0][
    ['driver_id', 'driving_test_score_10']
]
# Out:
# Empty DataFrame
# Columns: [driver_id, driving_test_score_10]
# Index: []

# %%
score_columns = [
    'communication_score_10',
    'driving_test_score_10',
    'route_knowledge_score_10',
    'customer_handling_score_10',
    'overall_interview_score_10'
]

df[score_columns] = df[score_columns].clip(upper=10)

for column in score_columns:
    print(
        column,
        "Min:", df[column].min(),
        "Max:", df[column].max()
    )
# Out:
# communication_score_10 Min: 0.1 Max: 10.0
# driving_test_score_10 Min: 0.1 Max: 10.0
# route_knowledge_score_10 Min: 0.1 Max: 10.0
# customer_handling_score_10 Min: 0.0 Max: 10.0
# overall_interview_score_10 Min: 0.1 Max: 10.0

# %% [markdown]
# # print(df.isna().sum())

# %%
## This converts the data type from object to string.
df['overall_driver_rating'] = df['overall_driver_rating'].astype(float)
print(df['overall_driver_rating'].dtype)
# Out:
# float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 33 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   driver_id                   50000 non-null  object
#  1   driver_name                 50000 non-null  object
#  2   age                         50000 non-null  int64
#  3   city                        50000 non-null  string
#  4   phone                       50000 non-null  string
#  5   email                       50000 non-null  string
#  6   platform                    50000 non-null  string
#  7   vehicle_type                50000 non-null  string
#  8   vehicle_condition           50000 non-null  string
#  9   experience_level            50000 non-null  string
#  10  preferred_shift             50000 non-null  string
#  11  reason_for_joining          50000 non-null  string
#  12  languages_known             50000 non-null  string
# ...

# %%
import matplotlib.pyplot as plt

df[["total_trips_completed", "onboarding_date"]].hist(bins=20)
plt.show()

# %%
## This code gives a visual representation of the distribution of total_trips_completed from their onboarding_date using a Histogram. 


import matplotlib.pyplot as plt

plt.hist(df["total_trips_completed"], bins=20, alpha=0.5, label="total_trips_completed")
plt.hist(df["onboarding_date"], bins=20, alpha=0.5, label="onboarding_date")

plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Distribution of total_trips_completed and 'onboarding_date'")
plt.legend()
plt.show()

# %%
## This code gives a visual representation of the values of total_trips_completed using a Histogram. 

import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(data=df, x='total_trips_completed')
plt.show()

# %%
## This code gives a visual representation of the values of the overall_driver_rating vs the total_complaints using a Bar chart. 

import matplotlib.pyplot as plt
# %matplotlib inline

plt.bar(df["overall_driver_rating"], df["total_complaints"])

plt.title("overall_driver_rating against total_complaints")
plt.xlabel("overall_driver_rating")
plt.ylabel("total_complaints")

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(data=df, y='city')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(data=df, x='driver_id', y='platform')
plt.show()

# %%
import seaborn as sns

sns.boxplot(data=df, x='languages_known')
plt.show()

# %%
## This code gives a visual representation of the various values on a Pie chart. 


import matplotlib.pyplot as plt

# Sample data
labels = ['city', 'customer_handling_score_10', 'overall_driver_rating', 'email', 'preferred_shift', 'communication_score_10', 'driver_name', 'experience_level', 'vehicle_condition','platform']
sizes = [10, 10, 10, 10,10, 10, 10, 10, 10,10]

# Plot
plt.pie(sizes, labels=labels)

# Show chart
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(df['age'], df['experience_level'])
plt.title("Driver's Age vs experience_level")
plt.xlabel("age")
plt.ylabel("experience_level")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(df['vehicle_type'], df['vehicle_condition'])
plt.title("vehicle_type vs vehicle_condition")
plt.xlabel("vehicle_type")
plt.ylabel("experience_level")
plt.show()

# %%
import matplotlib.pyplot as plt

import seaborn as sns

sns.barplot(data=df, x='customer_handling_score_10', y='route_knowledge_score_10')
plt.xlabel("customer_handling_score_10") 
plt.ylabel("route_knowledge_score_10")
plt.show()

# %%
sns.violinplot(x='age',y='experience_level', data=df)

plt.xlabel("age") 
plt.ylabel("experience_level")
plt.show()

# %%
## Heatmap is only used for numerical columns.

import seaborn as sns

plt.figure(figsize=(12,8))
sns.heatmap(df.corr(numeric_only=True),
            annot=True,
            cmap='coolwarm')
plt.show()

# %%
#df.to_csv("uber_rapido_driver_cleaned.csv",index=False)

# %%
# Machine learning is a branch of data engineering/data science where we feed data to a model so it can make predictions or take actions on its own. 
# ML Models are Python libraries that find patterns or correlations in data to classify, make predictions, and plot graphs.
# Examples of models are LogisticRegression, RandomForestRegressor, K-NearestNeighborsRegressor, AdaBoostRegressor, LinearRegression, BaggingRegressor, etc

# The first step in machine learning prediction is to determine what you intend to predict and then select your X and Y in the dataset.
# For appropriate model selection, you must first determine whether it is a regression or classification problem. ****
# (Model selection: in order to select the appropriate model, you must first analyse the dataset and know how to which model fits best)
# X represents the data, columns, or values you want to use for predictions.
# Y represents the column you want to predict.

# The second step is where you now do the splitting.
# We have the X_train and X_test
# Where X_Train stands for the percentage of data (80%) which the model uses for training
# X_test represents the percentage of data (20%) which the model uses for testing and value prediction.
# To split the bunch of data into X_train and X_test, we use the train_test_split function imported from sklearn.model_selection.

# The third step is MODEL SELECTION (import model, e.g from sklearn.linear_model import LogisticRegression).

# The Fourth step will be the fit_step (fitting the data into the model)

# The fifth step is the prediction step to get the results you want.

# The final step is to plot the graph for visualisation.

# Example: Let's predict overall_driver_rating using: 
        #'age',
        #'trips_completed',
        #'communication_score'
        #'driving_test_score_10'         
        #route_knowledge_score_10      
        #customer_handling_score_10    
        #overall_interview_score_10

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.ensemble import BaggingRegressor
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)


# -----------------------------------------
# 1. Select features and target
# -----------------------------------------

X = df[[
        'communication_score_10',
        'driving_test_score_10',         
        'route_knowledge_score_10',      
        'customer_handling_score_10',    
        'overall_interview_score_10'
]]

y = df['overall_driver_rating']


# -----------------------------------------
# 2. Check the data
# -----------------------------------------

print("Missing values:")
print(X.isna().sum())

print("\nData types:")
print(X.dtypes)


# -----------------------------------------
# 3. Split training and testing data
# -----------------------------------------

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)


# -----------------------------------------
# 4. Create BaggingRegressor
# -----------------------------------------

model = BaggingRegressor(
    n_estimators=100,
    random_state=42
)


# -----------------------------------------
# 5. Train model
# -----------------------------------------

model.fit(X_train, y_train)


# -----------------------------------------
# 6. Make predictions
# -----------------------------------------

y_pred = model.predict(X_test)


# -----------------------------------------
# 7. Evaluate model
# -----------------------------------------

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("\nMODEL PERFORMANCE")
print("-----------------")
print("MAE:", mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R² Score:", r2)

# -----------------------------------------
# 8. Compare actual and predicted values
# -----------------------------------------

results = pd.DataFrame({
    'Actual_Rating': y_test,
    'Predicted_Rating': y_pred
})

#results['Error'] = (
    #results['Actual_Rating'] -
    #results['Predicted_Rating']
#)

print("\nPredictions:")
print(results.head(20))


# -----------------------------------------
# 9. Actual vs predicted plot
# -----------------------------------------

plt.figure(figsize=(8, 6))

plt.scatter(
    y_test,
    y_pred,
    alpha=0.6
)

min_val = min(y_test.min(), y_pred.min())
max_val = max(y_test.max(), y_pred.max())

plt.plot(
    [min_val, max_val],
    [min_val, max_val],
    linewidth=2
)

plt.xlabel("Actual Driver Rating")
plt.ylabel("Predicted Driver Rating")
plt.title("BaggingRegressor: Actual vs Predicted Driver Ratings")

plt.show()
# Out:
# Missing values:
# communication_score_10        0
# driving_test_score_10         0
# route_knowledge_score_10      0
# customer_handling_score_10    0
# overall_interview_score_10    0
# dtype: int64
#
# Data types:
# communication_score_10        Float64
# driving_test_score_10         Float64
# route_knowledge_score_10      Float64
# customer_handling_score_10    Float64
# overall_interview_score_10    Float64
# dtype: object
#
# MODEL PERFORMANCE
# -----------------
# MAE: 1.1468497697619042
# MSE: 2.3596927846791114
# RMSE: 1.5361291562492756
# R² Score: -0.02695112074580419
#
# Predictions:
#        Actual_Rating  Predicted_Rating
# 33553            2.6          3.909000
# 9427             3.1          3.685000
# 199              3.9          4.452000
# 12447            7.7          5.100000
# 39489            3.2          4.467000
# 42724            4.6          3.907000
# 10822            4.3          4.135000
# 49498            3.2          4.513000
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostRegressor
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)


# -----------------------------------------
# 1. Select features and target
# -----------------------------------------

X = df[[
        'communication_score_10',
        'driving_test_score_10',         
        'route_knowledge_score_10',      
        'customer_handling_score_10',    
        'overall_interview_score_10'
]]

y = df['overall_driver_rating']


# -----------------------------------------
# 2. Check the data
# -----------------------------------------

print("Missing values:")
print(X.isna().sum())

print("\nData types:")
print(X.dtypes)


# -----------------------------------------
# 3. Split training and testing data
# -----------------------------------------

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)


# -----------------------------------------
# 4. Create AdaBoost model
# -----------------------------------------

model = AdaBoostRegressor(
    n_estimators=100,
    learning_rate=0.1,
    random_state=42
)


# -----------------------------------------
# 5. Train model
# -----------------------------------------

model.fit(X_train, y_train)


# -----------------------------------------
# 6. Make predictions
# -----------------------------------------

y_pred = model.predict(X_test)


# -----------------------------------------
# 7. Evaluate model
# -----------------------------------------

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("\nMODEL PERFORMANCE")
print("-----------------")
print("MAE:", mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R² Score:", r2)

# -----------------------------------------
# 8. Compare actual and predicted values
# -----------------------------------------

results = pd.DataFrame({
    'Actual_Rating': y_test,
    'Predicted_Rating': y_pred
})

#results['Error'] = (
    #results['Actual_Rating'] -
    #results['Predicted_Rating']
#)

print("\nPredictions:")
print(results.head(20))


# -----------------------------------------
# 9. Actual vs predicted plot
# -----------------------------------------

plt.figure(figsize=(8, 6))

plt.scatter(
    y_test,
    y_pred,
    alpha=0.6
)

min_val = min(y_test.min(), y_pred.min())
max_val = max(y_test.max(), y_pred.max())

plt.plot(
    [min_val, max_val],
    [min_val, max_val],
    linewidth=2
)

plt.xlabel("Actual Driver Rating")
plt.ylabel("Predicted Driver Rating")
plt.title("AdaBoost: Actual vs Predicted Driver Ratings")

plt.show()


# -----------------------------------------
# 10. Feature importance
# -----------------------------------------

importance = pd.DataFrame({
    'Feature': X.columns,
    'Importance': model.feature_importances_
})

importance = importance.sort_values(
    by='Importance',
    ascending=False
)

print("\nFeature Importance:")
print(importance)
# Out:
# Missing values:
# communication_score_10        0
# driving_test_score_10         0
# route_knowledge_score_10      0
# customer_handling_score_10    0
# overall_interview_score_10    0
# dtype: int64
#
# Data types:
# communication_score_10        Float64
# driving_test_score_10         Float64
# route_knowledge_score_10      Float64
# customer_handling_score_10    Float64
# overall_interview_score_10    Float64
# dtype: object
#
# MODEL PERFORMANCE
# -----------------
# MAE: 1.182619610686117
# MSE: 2.3827568706596605
# RMSE: 1.5436181103691613
# R² Score: -0.03698873627799881
# y_test: float64
# y_pred: float64
#
# Predictions:
#        Actual_Rating  Predicted_Rating
# 33553            2.6          4.424063
# 9427             3.1          4.493228
# 199              3.9          4.452006
# 12447            7.7          4.372680
# 39489            3.2          4.353165
# 42724            4.6          4.445918
# 10822            4.3          4.452006
# ...
