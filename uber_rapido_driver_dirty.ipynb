# %%
import pandas as pd

#import matplotlib.pyplot as plt

df = pd.read_csv("uber_rapido_driver_dirty.csv")
df.head(5)
# Out:
#    driver_id       driver_name  age       city       phone  \
# 0  DRV016649    Naresh Chauhan  NaN    Chennai  9255500096
# 1  DRV032785        Amit Gupta   45  Ahmedabad  9940345570
# 2  DRV011323     Yogesh Nair     53    Lucknow  9170487337
# 3  DRV022168       Manoj Patel   46  Hyderabad  9246425981
# 4  DRV040782  Vikram Chaudhary   25    KOLKATA     9282240
#
#                         email platform vehicle_type vehicle_condition  \
# 0  naresh.chauhan@hotmail.com     uber         auto              good
# 1   amit.gupta@rediffmail.com     Uber        Mini          Excellent
# 2                         NaN     uber          SUV               avg
# 3     manoj.patel@hotmail.com   RAPIDO         Mini               NaN
# 4  vikram.chaudhary@gmail.com    Uber           suv              GOOD
#
#   experience_level  ... driving_test_score_10 route_knowledge_score_10  \
# 0           0-1 yr  ...                   4.3                      5.8
# 1          Fresher  ...                   9.3                      NaN
# 2           0-1 yr  ...                   6.3                      9.0
# 3          1-3 yrs  ...                   8.7                      9.6
# 4          Fresher  ...                  12.7                      6.5
#
#   customer_handling_score_10 overall_interview_score_10  \
# 0                        7.7                        5.3
# 1                        9.0                        8.1
# 2                        5.5                        6.9
# 3                        5.3                        7.8
# 4                        7.9                        6.0
#
#    document_verification  background_check_status  interview_result  \
# 0                   Fail                      NaN           On Hold
# 1                    NaN                    Clear           On Hold
# 2                    NaN                    clear          Selected
# 3                unknown                    Clear          Selected
# 4                   FAIL                    clear          Rejected
#
#      rejection_reason  onboarding_date  is_currently_active
# 0                 NaN                -                false
# 1                 NaN                -                   No
# 2                 NaN    19 April 2021                false
# 3                 NaN       2021/05/27                    0
# 4  Low rating history                -                   NO
#
# [5 rows x 33 columns]

# %%
df.describe()
# Out:
#        total_trips_completed  trip_completion_rate_%  cancellation_rate_%  \
# count           45930.000000             45565.00000         45484.000000
# mean             6802.510799                77.89254            22.416584
# std             17638.171153                20.80393            23.708155
# min             -7996.000000                -2.00000            -2.000000
# 25%              1704.000000                69.40000             8.100000
# 50%              3909.000000                80.50000            18.100000
# 75%              6086.750000                91.60000            27.900000
# max             99999.000000               103.00000           103.000000
#
#        total_complaints  total_compliments  communication_score_10  \
# count      45965.000000       46024.000000            45416.000000
# mean        8809.843120        8942.686272                6.508777
# std        28303.698509       28456.710282                2.789817
# min            0.000000           0.000000               -2.000000
# 25%           14.000000          27.000000                4.600000
# 50%           27.000000          55.000000                6.600000
# 75%           41.000000          82.000000                8.500000
# max        99999.000000       99999.000000               13.000000
#
#        driving_test_score_10  route_knowledge_score_10  \
# count           45559.000000              45448.000000
# mean                6.946878                  6.508619
# std                 2.630277                  2.794014
# min                -2.000000                 -2.000000
# 25%                 5.400000                  4.600000
# 50%                 7.100000                  6.600000
# 75%                 8.800000                  8.600000
# max                13.000000                 13.000000
#
#        customer_handling_score_10  overall_interview_score_10
# count                45500.000000                45545.000000
# mean                     6.517708                    6.613859
# std                      2.804085                    2.239486
# min                     -2.000000                   -2.000000
# 25%                      4.600000                    5.900000
# 50%                      6.600000                    6.700000
# 75%                      8.600000                    7.400000
# max                     13.000000                   13.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 33 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   driver_id                   49005 non-null  object
#  1   driver_name                 50000 non-null  object
#  2   age                         47543 non-null  object
#  3   city                        50000 non-null  object
#  4   phone                       46089 non-null  object
#  5   email                       45395 non-null  object
#  6   platform                    47761 non-null  object
#  7   vehicle_type                47775 non-null  object
#  8   vehicle_condition           39468 non-null  object
#  9   experience_level            47776 non-null  object
#  10  preferred_shift             38773 non-null  object
#  11  reason_for_joining          38637 non-null  object
#  12  languages_known             47847 non-null  object
#  13  overall_driver_rating       46033 non-null  object
#  14  total_trips_completed       45930 non-null  float64
#  15  trip_completion_rate_%      45565 non-null  float64
#  16  cancellation_rate_%         45484 non-null  float64
#  17  avg_daily_earnings_INR      47489 non-null  object
#  18  total_complaints            45965 non-null  float64
#  19  total_compliments           46024 non-null  float64
#  20  peak_hour_availability      50000 non-null  object
#  21  interview_date              45067 non-null  object
#  22  communication_score_10      45416 non-null  float64
#  23  driving_test_score_10       45559 non-null  float64
#  24  route_knowledge_score_10    45448 non-null  float64
#  25  customer_handling_score_10  45500 non-null  float64
#  26  overall_interview_score_10  45545 non-null  float64
#  27  document_verification       36233 non-null  object
#  28  background_check_status     36549 non-null  object
#  29  interview_result            45243 non-null  object
#  30  rejection_reason            12174 non-null  object
#  31  onboarding_date             26172 non-null  object
#  32  is_currently_active         50000 non-null  object
# dtypes: float64(10), object(23)
# memory usage: 12.6+ MB

# %%
df.shape
# Out:
# (50000, 33)

# %%
df['email'].unique()
# Out:
# <StringArray>
# [  'naresh.chauhan@hotmail.com',    'amit.gupta@rediffmail.com',
#     '  Yogesh Nair  @gmail.com',      'manoj.patel@hotmail.com',
#    'vikram.chaudhary@gmail.com',   'sanjay.chaudhary@yahoo.com',
#    'rakesh.chaudhary@gmail.com',    'naveen.mishra@hotmail.com',
#        'Hitesh Singh@gmail.com',     'harish.chauhan@gmail.com',
#  ...
#       'naveen.singh@@gmail.com',         'manoj.jha@@gmail.com',
#          'naresh.gupta@hotmail',      'RAMESH TIWARI@gmail.com',
#            'mahesh.kumar@gmail',           'harish.kumar@yahoo',
#     'ANIL SRIVASTAVA@gmail.com', 'deepak.srivastavahotmail.com',
#         'deepak.singhgmail.com',        'deepak.dubeygmail.com']
# Length: 8553, dtype: string

# %%
df['email'] = df['email'].astype("string")
print(df['email'].dtype)
# Out:
# string

# %%
##This code creates a gmail adrress for the drivers using their names, where they have no existing emails.

df['email'] = df['email'].fillna(
    df['driver_name'] + '@gmail.com'
)
df.sample(1000)
# Out:
#        driver_id         driver_name  age       city       phone  \
# 45650  DRV044996          Anil Yadav   36  BANGALORE         NaN
# 19683  DRV030353     Mukesh Tripathi   25     Chenna  9300498539
# 21021  DRV013455        Dinesh Kumar   52     Jaipur  9271651407
# 19198  DRV049301  Pradeep Srivastava   54      Delhi  9263574619
# 5712   DRV001268        Pankaj Kumar   37     Jaipur  9896107802
# ...          ...                 ...  ...        ...         ...
# 14599        NaN      Umesh Tripathi  -25     Jaipur  9327414765
# 2693   DRV005770            R@vi Jh@   31     Mumbai  9819399790
# 45482  DRV015081   Dinesh Srivastava   45  Ahmedabad     9657357
# 20777  DRV035403       Ramesh Shukla  -40  Ahmedabad         NaN
# 25883  DRV023747       dinesh tiwari   39    Chennai  9417432144
#
#                                    email       platform vehicle_type  \
# 45650          anil.yadav@rediffmail.com           Uber        sedan
# 19683          mukesh.tripathi@yahoo.com  Uber & Rapido        Sedan
# 21021             Dinesh Kumar@gmail.com        Rapido          auto
# 19198  pradeep.srivastava@rediffmail.com  Uber & Rapido         auto
# 5712              pankaj.kumar@gmail.com           Uber        sedan
# ...                                  ...            ...          ...
# 14599           umesh.tripathi@yahoo.com           Uber        Mini
# 2693                  ravi.jha@gmail.com             na        Mini
# 45482        dinesh.srivastava@gmail.com         Rapido         Auto
# 20777          ramesh.shukla@hotmail.com         Rapido        Sedan
# 25883          dinesh.tiwari@hotmail.com  Uber & Rapido        sedan
#
#       vehicle_condition experience_level  ... driving_test_score_10  \
# 45650              Poor          Fresher  ...                   9.1
# 19683              good          3-5 yrs  ...                   9.6
# 21021              Poor          Fresher  ...                   NaN
# 19198           unknown          1-3 yrs  ...                   8.0
# 5712            Average          1-3 yrs  ...                   5.3
# ...                 ...              ...  ...                   ...
# 14599               avg          3-5 yrs  ...                   8.3
# 2693                NaN           0-1 yr  ...                   8.5
# 45482              Good          Fresher  ...                  -1.9
# 20777              GOOD           0-1 yr  ...                   6.6
# 25883           Average          3-5 yrs  ...                   9.7
#
#       route_knowledge_score_10 customer_handling_score_10  \
# 45650                      6.0                        6.3
# 19683                      4.4                        3.5
# 21021                     12.6                        8.6
# 19198                      8.8                        6.9
# 5712                      -0.7                       -1.4
# ...                        ...                        ...
# 14599                      3.2                        4.9
# 2693                       9.1                        9.8
# 45482                      5.7                        4.6
# 20777                     10.2                       -1.0
# 25883                      3.1                        6.4
#
#       overall_interview_score_10  document_verification  \
# 45650                        6.9                    NaN
# 19683                        5.3                Pending
# 21021                        6.7                    NaN
# 19198                        7.9                   Pass
# 5712                        11.5                Pending
# ...                          ...                    ...
# 14599                        6.5                   Fail
# 2693                         8.3                    NaN
# 45482                        5.7                    NaN
# 20777                        6.6                   pass
# 25883                        7.2                   FAIL
#
#        background_check_status  interview_result      rejection_reason  \
# 45650                  FLAGGED               NaN                   NaN
# 19683                  FLAGGED           On Hold                   NaN
# 21021                  FLAGGED           On Hold                   NaN
# 19198                  pending           On Hold                   NaN
# 5712                   pending          Rejected                   NaN
# ...                        ...               ...                   ...
# 14599                  pending          Selected                   NaN
# 2693                       NaN          Rejected    Low rating history
# 45482                  pending           On Hold                   NaN
# 20777                  Flagged          Rejected  Incomplete documents
# 25883                    Clear          Selected                   NaN
#
#             onboarding_date  is_currently_active
# 45650  2021-11-08T00:00:00Z                    1
# 19683                   NaN                false
# 21021                   NaN                  YES
# 19198                     -                False
# 5712                    NaN                    0
# ...                     ...                  ...
# 14599           August 2023                False
# 2693                      -                   NO
# 45482                     -                false
# 20777                   NaN                    N
# 25883            March 2023                  YES
#
# [1000 rows x 33 columns]

# %%
df.sample(10)
# Out:
#        driver_id        driver_name     age       city           phone  \
# 11784  DRV012779         Naresh Rao      55      Delhi      9031005608
# 3955   DRV047199        Vijay Patel      31  Bangalore      9687783655
# 21665  DRV016471         Vijay Nair  26 yrs    Lucknow      XXXXXXXXXX
# 13248  DRV000468        sunil dubey      54       Pune      9066943321
# 36470  DRV002660       Bharat Kumar      27    chennai         9047805
# 5754   DRV032255    Santosh Singh        33  Hyderabad      9154722900
# 210    DRV036001   H@rish Ch@udh@ry      20  bangalore  +91-9954686687
# 12185  DRV046637       Mukesh Patel      36  Hyderabad      9663172010
# 34024  DRV004865         Ravi Verma     999     Jaipur             NaN
# 23640  DRV044411      Pradeep Verma      30       Pune      9297127377
#
#                                  email       platform vehicle_type  \
# 11784             naresh.rao@yahoo.com         rapido        Mini
# 3955        vijay.patel@rediffmail.com         RAPIDO         Auto
# 21665             Vijay Nair@gmail.com           Uber          suv
# 13248            sunil.dubey@yahoo.com  Uber & Rapido          suv
# 36470           bharat.kumar@yahoo.com           uber          SUV
# 5754      santosh.singh@rediffmail.com           uber         Auto
# 210    harish.chaudhary@rediffmail.com           UBER         Mini
# 12185            mukesh.patelgmail.com        Rapido         Mini
# 34024                 ravi.verma@yahoo           UBER         BIKE
# 23640          pradeep.verma@yahoo.com          Uber          auto
#
#       vehicle_condition experience_level  ... driving_test_score_10  \
# 11784               NaN           5+ yrs  ...                   8.5
# 3955          Excellent           5+ yrs  ...                   8.4
# 21665               avg          1-3 yrs  ...                   NaN
# 13248               avg          Fresher  ...                   NaN
# 36470         excellent           0-1 yr  ...                   8.0
# 5754               good          3-5 yrs  ...                   7.6
# 210                Poor          3-5 yrs  ...                   5.9
# 12185           Average           5+ yrs  ...                   6.7
# 34024              Good              NaN  ...                   7.4
# 23640         excellent           0-1 yr  ...                   8.4
#
#       route_knowledge_score_10 customer_handling_score_10  \
# 11784                      9.6                        4.5
# 3955                       5.4                        6.6
# 21665                      6.9                        8.8
# 13248                      7.3                       -1.4
# 36470                      5.4                        4.5
# 5754                       4.9                        NaN
# 210                       11.0                        5.5
# 12185                      8.2                        4.6
# 34024                      4.2                        6.9
# 23640                      3.9                        3.3
#
#       overall_interview_score_10  document_verification  \
# 11784                        7.0                Pending
# 3955                         5.8                   FAIL
# 21665                       -1.7                Pending
# 13248                        5.1                   FAIL
# 36470                        6.6                   Fail
# 5754                         6.1                pending
# 210                          5.9                   Pass
# 12185                        6.1                    NaN
# 34024                        6.3                   none
# 23640                        4.8                   Fail
#
#        background_check_status  interview_result    rejection_reason  \
# 11784                      NaN           On Hold                 NaN
# 3955                       NaN          Waitlist  Poor communication
# 21665                    Clear           On Hold                 NaN
# 13248                      NaN          Selected                 NaN
# 36470                  FLAGGED           On Hold                 NaN
# 5754                     clear          Selected                 NaN
# 210                    Pending               NaN                  na
# 12185                  pending          Selected                 NaN
# 34024                    clear          Waitlist      Not applicable
# 23640                      NaN          Rejected                none
#
#        onboarding_date  is_currently_active
# 11784              NaN                    1
# 3955               NaN                    1
# 21665    15 March 2022                   NO
# 13248         02/07/24                 true
# 36470              NaN                    1
# 5754        11-08-2022                false
# 210                  -                  Yes
# 12185              NaN                false
# 34024              NaN                   No
# 23640              NaN                  YES
#
# [10 rows x 33 columns]

# %%
df['phone'] = pd.to_numeric(df['phone'], errors='coerce') 
## This is to convert the phone collumn from object to numeric

# %%
df['phone'] = df['phone'].astype("string")
print(df['phone'].dtype)
# Out:
# string

# %%
df['driving_test_score_10'].unique()
# Out:
# <StringArray>
# [ '4.3',  '9.3',  '6.3',  '8.7', '12.7',  '8.8',  '8.1',  '1.1', '11.6',
#    <NA>,
#  ...
#  '12.3',  '1.6', '12.6',  '1.9', '10.6', '12.9', '11.1', '13.0',  '0.1',
#   '2.0']
# Length: 112, dtype: string

# %%
## This code removes the decimals from the values and make them strings rather than floats. 
df['phone'] = df['phone'].str.replace(r'\.0$', '', regex=True)

# %%
## This creates random phone numbers for NaN values in the phone column

import numpy as np

mask = df['phone'].isna()

df.loc[mask, 'phone'] = [
    '+91' + ''.join(np.random.choice(list('0123456789'), 9))
    for _ in range(mask.sum())
]
df.sample(1000)
# Out:
#        driver_id       driver_name  age       city         phone  \
# 14725  DRV014548       Sunil Patel  999    Kolkata    9714338218
# 19828  DRV001352      Naveen Gupta   42     Mumbai    9610711382
# 45429  DRV009964        Ravi Gupta  NaN       Pune  +91442976823
# 44856  DRV009020      Ganesh Dubey  -26     Mumbai    9857372281
# 13671  DRV015759        Yogesh Rao   36    LUCKNOW    9128700620
# ...          ...               ...  ...        ...           ...
# 1631   DRV049954  Bharat Chaudhary   20     Jaipur    9969331038
# 48579  DRV049411     Santosh Reddy   39    LUCKNOW    9545125271
# 16819  DRV048414    Anil Chaudhary   45       Pune    9623372008
# 34915  DRV004091     Rakesh Mishra   42  Hyderabad    9952664948
# 39248  DRV005748   Sanjay Tripathi   32       Pune    9883930795
#
#                              email platform vehicle_type vehicle_condition  \
# 14725       sunil.patelhotmail.com     none         Mini              Good
# 19828       naveen.gupta@gmail.com     UBER        Mini          excellent
# 45429         ravi.gupta@gmail.com   Rapido        Mini                avg
# 44856  ganesh.dubey@rediffmail.com   RAPIDO         Bike              poor
# 13671        yogesh.rao@@gmail.com     uber          SUV              none
# ...                            ...      ...          ...               ...
# 1631   bharat.chaudhary@@yahoo.com   rapido         BIKE         excellent
# 48579      santosh.reddy@gmail.com    Uber           SUV           Average
# 16819   anil.chaudhary@hotmail.com   rapido          NaN              Good
# 34915      rakesh.mishra@yahoo.com   rapido          suv         Excellent
# 39248    sanjay.tripathi@gmail.com   rapido        sedan           Average
#
#       experience_level  ... driving_test_score_10 route_knowledge_score_10  \
# 14725          3-5 yrs  ...                   NaN                      3.7
# 19828          1-3 yrs  ...                   7.0                      8.3
# 45429          Fresher  ...                   6.4                      NaN
# 44856          1-3 yrs  ...                   5.9                     -1.9
# 13671          1-3 yrs  ...                   NaN                      5.0
# ...                ...  ...                   ...                      ...
# 1631           Fresher  ...                   7.4                      4.8
# 48579          1-3 yrs  ...                   5.3                      4.0
# 16819          1-3 yrs  ...                   5.2                      4.1
# 34915           0-1 yr  ...                   4.5                      NaN
# 39248          1-3 yrs  ...                   5.5                      3.9
#
#       customer_handling_score_10 overall_interview_score_10  \
# 14725                        9.5                        6.7
# 19828                        4.4                        5.9
# 45429                        4.6                        6.0
# 44856                        7.9                        6.5
# 13671                       10.0                        6.5
# ...                          ...                        ...
# 1631                         5.7                        6.8
# 48579                        5.0                        5.3
# 16819                        5.4                       -1.1
# 34915                        4.0                       12.3
# 39248                       12.6                        7.0
#
#        document_verification  background_check_status  interview_result  \
# 14725                    NaN                      NaN           On Hold
# 19828                   Fail                  pending          Rejected
# 45429                   Pass                    clear          Selected
# 44856                   FAIL                      NaN           On Hold
# 13671                   Pass                  pending           On Hold
# ...                      ...                      ...               ...
# 1631                 Pending                      NaN                 -
# 48579                   Pass                  Pending          Rejected
# 16819                   FAIL                      NaN           On Hold
# 34915                pending                  FLAGGED          Rejected
# 39248                    NaN                    Clear          Rejected
#
#           rejection_reason  onboarding_date  is_currently_active
# 14725                  NaN              NaN                false
# 19828                  NaN              NaN                false
# 45429                  NaN    February 2022                 True
# 44856                  NaN              NaN                   no
# 13671                  NaN              NaN                   NO
# ...                    ...              ...                  ...
# 1631                   NaN       2023/08/17                  yes
# 48579  Vehicle age too old              NaN                    1
# 16819                  NaN              NaN                   No
# 34915                  NaN              NaN                   no
# 39248   Poor communication              NaN                    N
#
# [1000 rows x 33 columns]

# %%
df['age'] = df['age'].astype("string")
print(df['age'].dtype)
# Out:
# string

# %%
df['age'] = df['age'].fillna('70')

# %%
## This code fills the age column where NaN values exist with random values between 1 and 100

import numpy as np

mask = df['age'].isna()

df.loc[mask, 'age'] = np.random.randint(
    1, 101, size=mask.sum()
)
df.sample(1000)
# Out:
#        driver_id        driver_name     age       city         phone  \
# 22326  DRV011762       PANKAJ PATEL      29     jaipur       9960349
# 34354  DRV013841    Girish Tripathi  33 yrs       Dlhi    9849609740
# 368    DRV047234       Hitesh Patel      30    Lucknow    9393479428
# 1446   DRV001154         Ravi Singh      45     Jaipur  +91657895337
# 9206   DRV044322      Naresh Pandey      32  Ahmedabad    9278605600
# ...          ...                ...     ...        ...           ...
# 8570   DRV014412    Deepak Shukla        35       Pune    9996347145
# 10972  DRV036833       Girish Dubey      44     Mumbai    9894212105
# 46911  DRV004487       P@nk@j P@tel      51  Ahmedabad  +91344143416
# 42146  DRV008361      Mukesh Shukla      70    Lucknow    9443938657
# 11510  DRV002663        SUNIL SINGH      41  Ahmedabad    9717714013
#
#                               email       platform vehicle_type  \
# 22326        pankaj.patel@gmail.com           uber        sedan
# 34354     girish.tripathi@yahoo.com         rapido         auto
# 368              hitesh.patel@gmail           Uber         Bike
# 1446           ravi.singh@gmail.com           Uber         Auto
# 9206        naresh.pandey@yahoo.com           uber         Mini
# ...                             ...            ...          ...
# 8570      deepak.shukla@hotmail.com         RAPIDO         Bike
# 10972        girish.dubey@gmail.com  Uber & Rapido          SUV
# 46911       pankaj.patel@@gmail.com            ola         auto
# 42146  mukesh.shukla@rediffmail.com        Rapido         Sedan
# 11510   sunil.singh@@rediffmail.com         Rapido         Auto
#
#       vehicle_condition experience_level  ... driving_test_score_10  \
# 22326               NaN           5+ yrs  ...                   5.4
# 34354         Excellent          unknown  ...                   9.1
# 368                poor          Fresher  ...                  11.8
# 1446               Poor           0-1 yr  ...                   5.9
# 9206               GOOD           5+ yrs  ...                   7.4
# ...                 ...              ...  ...                   ...
# 8570          Excellent          1-3 yrs  ...                   7.2
# 10972         excellent          3-5 yrs  ...                  11.9
# 46911              Poor           5+ yrs  ...                   NaN
# 42146              Good          Fresher  ...                   8.4
# 11510               avg          3-5 yrs  ...                   5.1
#
#       route_knowledge_score_10 customer_handling_score_10  \
# 22326                      3.9                        6.2
# 34354                      4.5                        5.5
# 368                        7.9                        9.0
# 1446                       3.7                        4.0
# 9206                       7.8                        3.5
# ...                        ...                        ...
# 8570                       5.5                        4.6
# 10972                      5.7                        5.3
# 46911                      6.2                        3.5
# 42146                     -0.7                        7.7
# 11510                      5.3                        9.5
#
#       overall_interview_score_10  document_verification  \
# 22326                        5.5                   pass
# 34354                       -0.3                   Fail
# 368                          8.5                pending
# 1446                         5.1                Pending
# 9206                         6.0                   pass
# ...                          ...                    ...
# 8570                         6.5                Pending
# 10972                        6.2                pending
# 46911                        5.5                    NaN
# 42146                        6.7                   pass
# 11510                        NaN                    NaN
#
#        background_check_status  interview_result     rejection_reason  \
# 22326                      NaN          REJECTED                  NaN
# 34354                    clear          Rejected   Low rating history
# 368                    FLAGGED           On Hold                  NaN
# 1446                       NaN               NaN                  NaN
# 9206                   Pending          REJECTED                  NaN
# ...                        ...               ...                  ...
# 8570                     Clear               NaN  Failed driving test
# 10972                  pending           on hold                 none
# 46911                  pending          Selected                  NaN
# 42146                  pending           On Hold                  NaN
# 11510                  Pending          Rejected                  NaN
#
#             onboarding_date  is_currently_active
# 22326              12/30/21                    N
# 34354                   NaN                   NO
# 368                     NaN                   No
# 1446             17.01.2022                False
# 9206   2022-03-20T00:00:00Z                   NO
# ...                     ...                  ...
# 8570                    NaN                false
# 10972                   NaN                  yes
# 46911         December 2023                  YES
# 42146                     -                   NO
# 11510                   NaN                    Y
#
# [1000 rows x 33 columns]

# %%
## This is to remove the negative values and also the yrs in the age column.
df['driving_test_score_10'] = df['driving_test_score_10'].astype("string")
df['driving_test_score_10'] = df['driving_test_score_10'].str.lstrip('-')
#df['age'] = df['age'].str.rstrip('yrs')
df.sample(1000)
# Out:
#        driver_id         driver_name     age       city         phone  \
# 33504  DRV027033        R@kesh Reddy      47    kolkata    9505885238
# 4321   DRV018781        Sanjay Dubey  39 yrs    Chennai  +91334705836
# 22210  DRV036785   Harish Srivastava      31      Delhi  +91598744936
# 29331  DRV029313     Naresh Pandey        49  Ahmedabad    9297128905
# 48994  DRV047442        Rakesh Gupta      36    Chennai  +91705997793
# ...          ...                 ...     ...        ...           ...
# 30081  DRV040856        Rajesh Verma      44       Pune    9793740211
# 3987   DRV007837        PANKAJ VERMA      51     Mumbai    9416954781
# 19200  DRV048629  Pradeep Srivastava      41    Chennai    9904554387
# 49819  DRV033889       Rajesh Tiwari      25    Kolkata    9655108339
# 20910  DRV044278        Sunil Pandey      20    Lucknow  +91830699211
#
#                                  email platform vehicle_type  \
# 33504      rakesh.reddy@rediffmail.com      NaN         Auto
# 4321           sanjay.dubey@rediffmail   RAPIDO         Auto
# 22210  harish.srivastavarediffmail.com  unknown        sedan
# 29331        naresh.pandey@hotmail.com     UBER         Auto
# 48994           rakesh.gupta@yahoo.com        -        sedan
# ...                                ...      ...          ...
# 30081           rajesh.verma@gmail.com  Rapido          Auto
# 3987            pankaj.verma@gmail.com      NaN        Sedan
# 19200     pradeep.srivastava@yahoo.com      ola         Mini
# 49819        rajesh.tiwari@hotmail.com  Unknown         Mini
# 20910      sunil.pandey@rediffmail.com      NaN         auto
#
#       vehicle_condition experience_level  ... driving_test_score_10  \
# 33504               avg          Unknown  ...                   4.4
# 4321          excellent          Fresher  ...                   5.3
# 22210              good          1-3 yrs  ...                   5.2
# 29331              GOOD             none  ...                  <NA>
# 48994           Unknown          1-3 yrs  ...                   8.8
# ...                 ...              ...  ...                   ...
# 30081              Poor           0-1 yr  ...                  10.2
# 3987                NaN          1-3 yrs  ...                  <NA>
# 19200         excellent           5+ yrs  ...                   7.3
# 49819         Excellent          1-3 yrs  ...                   9.1
# 20910         excellent           0-1 yr  ...                   6.7
#
#       route_knowledge_score_10 customer_handling_score_10  \
# 33504                     10.0                       -1.8
# 4321                       5.8                        6.1
# 22210                      7.0                        NaN
# 29331                      7.9                        5.3
# 48994                      8.4                        8.6
# ...                        ...                        ...
# 30081                      4.2                        6.6
# 3987                       6.7                        8.0
# 19200                      4.0                        9.0
# 49819                      7.0                        7.4
# 20910                      NaN                        5.0
#
#       overall_interview_score_10  document_verification  \
# 33504                        7.6                   pass
# 4321                         6.8                    NaN
# 22210                        5.8                    NaN
# 29331                        7.5                   Pass
# 48994                        8.8                    NaN
# ...                          ...                    ...
# 30081                        7.4                Pending
# 3987                        -1.1                    NaN
# 19200                       10.9                pending
# 49819                        8.2                   FAIL
# 20910                        NaN                    NaN
#
#        background_check_status  interview_result    rejection_reason  \
# 33504                  FLAGGED          Selected                 NaN
# 4321                       NaN           On Hold                 NaN
# 22210                      NaN          Waitlist                 NaN
# 29331                  Pending           On Hold                 NaN
# 48994                    clear          Selected                 NaN
# ...                        ...               ...                 ...
# 30081                  Flagged          Selected                 NaN
# 3987                   Pending          Rejected  Low rating history
# 19200                    Clear          Selected                 NaN
# 49819                  Flagged          Selected                 NaN
# 20910                  FLAGGED           Unknown                 NaN
#
#             onboarding_date  is_currently_active
# 33504            25-02-2024                  Yes
# 4321                      -                    N
# 22210            2021/06/21                   no
# 29331                   NaN                  YES
# 48994              09/27/21                   No
# ...                     ...                  ...
# 30081  2021-09-14T00:00:00Z                   NO
# 3987                    NaN                False
# 19200              07/24/22                False
# 49819            26-10-2021                   NO
# 20910                   NaN                  yes
#
# [1000 rows x 33 columns]

# %%
## This is to capitalise the platform column to give it a uniform format and also convert the data type from object to string.

df['platform'] = df['platform'].str.capitalize()
df['platform'] = df['platform'].astype("string")
print(df['platform'].dtype)
# Out:
# string

# %%
df['platform'] = df['platform'].fillna('Bolt')

# %%
df['customer_handling_score_10'] = df['customer_handling_score_10'].replace({
   #'NaN': '70',
   # 'Mini ': 'Trailer',
    #'unknown': '80',
    #'999' : '90',
    #'Unknown': 'Experienced',
    #'None': 'Fairly_Experienced',
    #'Avg': 'Average',
    #'poor': 'Super',
    #'Unknown': 'Motorcycle',
    #'Na': '1-20 yrs',
    #'-': '10-30 yrs',
    #"<NA>": 'Bus',
    #'Auto': '',
    #'suv' : 'SUV'
    #'uber': '',
    '<NA>': '6'
})
df.sample(10000)
# Out:
#        driver_id     driver_name  age       city         phone  \
# 39448  DRV009634      Vikram Rao   54    Lucknow  +91135454480
# 21552  DRV004531    Yogesh Verma   24       Pune    9372040330
# 11903  DRV018370    Harish Singh   22     jaipur    9558946341
# 18844  DRV011054     Vijay Kumar   70    KOLKATA    9543004938
# 42588  DRV013318    Lokesh Gupta   26      Delhi    9627494250
# ...          ...             ...  ...        ...           ...
# 3088   DRV005632   Ramesh Sharma  -28  Ahmedabad  +91128341171
# 20823  DRV035628    Amit Gupta     39      DELHI       9182461
# 13177  DRV042543    SANJAY REDDY   36     jaipur  +91138216386
# 42268  DRV048632    Mahesh Gupta   50  Hyderabad    9171281542
# 34565  DRV013205   ganesh shukla   32     Jaipur    9611177757
#
#                              email       platform vehicle_type  \
# 39448           vikram.rao@hotmail           Uber         BIKE
# 21552       Yogesh Verma@gmail.com  Uber & rapido         Mini
# 11903       harish.singh@yahoo.com  Uber & rapido        Sedan
# 18844       vijay.kumar@rediffmail            Ola          SUV
# 42588  lokesh.gupta@rediffmail.com         Rapido        Sedan
# ...                            ...            ...          ...
# 3088       Ramesh Sharma@gmail.com            Ola         Bike
# 20823         amit.gupta@yahoo.com         Rapido        Mini
# 13177       sanjay.reddy@gmail.com         Rapido         auto
# 42268  mahesh.gupta@rediffmail.com           Uber         Mini
# 34565    ganesh.shukla@hotmail.com           Uber         BIKE
#
#       vehicle_condition experience_level  ... driving_test_score_10  \
# 39448           unknown          3-5 yrs  ...                   9.7
# 21552              Poor           0-1 yr  ...                   9.4
# 11903         excellent          3-5 yrs  ...                   9.7
# 18844              GOOD          Fresher  ...                   4.5
# 42588         excellent           0-1 yr  ...                   5.0
# ...                 ...              ...  ...                   ...
# 3088          excellent          3-5 yrs  ...                   5.9
# 20823         excellent           5+ yrs  ...                   4.1
# 13177                 -           0-1 yr  ...                   7.7
# 42268              Poor           5+ yrs  ...                   6.8
# 34565               NaN          1-3 yrs  ...                   7.6
#
#       route_knowledge_score_10 customer_handling_score_10  \
# 39448                      3.4                       10.6
# 21552                     -0.6                        5.3
# 11903                      3.4                        6.8
# 18844                      4.9                        4.9
# 42588                      3.8                        NaN
# ...                        ...                        ...
# 3088                       8.4                        5.8
# 20823                      9.3                        8.4
# 13177                      8.3                        5.7
# 42268                      8.0                        3.3
# 34565                      8.4                       10.0
#
#       overall_interview_score_10  document_verification  \
# 39448                        6.9                    NaN
# 21552                        5.4                    NaN
# 11903                       -0.9                   Pass
# 18844                        5.1                pending
# 42588                        4.7                    NaN
# ...                          ...                    ...
# 3088                         6.4                   FAIL
# 20823                       -1.9                Pending
# 13177                        7.2                    NaN
# 42268                        5.4                   Fail
# 34565                        8.2                    NaN
#
#        background_check_status  interview_result     rejection_reason  \
# 39448                    clear               NaN                  NaN
# 21552                    Clear          Rejected                 none
# 11903                  FLAGGED               NaN                  NaN
# 18844                  Pending           On Hold                  NaN
# 42588                      NaN           Unknown  Vehicle age too old
# ...                        ...               ...                  ...
# 3088                       NaN          Rejected                  NaN
# 20823                  pending                 -                  NaN
# 13177                    clear          Selected                  NaN
# 42268                  Pending           On Hold                  NaN
# 34565                      NaN          Selected                  NaN
#
#             onboarding_date  is_currently_active
# 39448  2021-05-02T00:00:00Z                   NO
# 21552                   NaN                    N
# 11903                     -                 True
# 18844                     -                false
# 42588                     -                    N
# ...                     ...                  ...
# 3088                    NaN                False
# 20823      18 November 2023                   NO
# 13177  2023-12-23T00:00:00Z                False
# 42268                   NaN                    0
# 34565                   NaN                   no
#
# [10000 rows x 33 columns]

# %%
## This capitalises the city column to give it a uniform format and also converts the data type from object to string.
df['city'] = df['city'].str.capitalize()
df['city'] = df['city'].astype("string")
df.sample(1000)
# Out:
#        driver_id       driver_name     age       city         phone  \
# 30320  DRV025043      Girish Verma      27    Kolkata  +91789581046
# 1286   DRV024905   Amit Srivastava      48  Hyderabad    9762516741
# 14922  DRV017565     Amit Tripathi      55    Kolkata    9163483907
# 4132   DRV003674      Mahesh Singh      31  Ahmedabad    9457710576
# 15089  DRV018147        rakesh rao      21       Pune    9215588743
# ...          ...               ...     ...        ...           ...
# 786    DRV016140  Ganesh Chaudhary  39 yrs     Chenna    9706237308
# 23059  DRV034006      Deepak Kumar      28      Delhi    9186742695
# 46657  DRV018590     Mahesh Mishra      32     Mumbai    9696313823
# 8350   DRV013275      Ganesh Kumar      28  Hyderabad    9888986703
# 28504  DRV023629  Yogesh Chaudhary      31       Pune    9866367332
#
#                               email platform vehicle_type vehicle_condition  \
# 30320   girish.verma@rediffmail.com   Rapido          suv              Good
# 1286      amit.srivastava@gmail.com     Uber        sedan              Poor
# 14922       amit.tripathi@gmail.com     Uber         Bike               NaN
# 4132    mahesh.singh@rediffmail.com     Uber         Auto         excellent
# 15089        rakesh.rao@hotmail.com   Rapido         Bike               NaN
# ...                             ...      ...          ...               ...
# 786    ganesh.chaudhary@hotmail.com  Unknown         BIKE               NaN
# 23059      deepak.kumar@hotmail.com     Uber         Bike                na
# 46657  mahesh.mishra@rediffmail.com     Uber      unknown              Good
# 8350    ganesh.kumar@rediffmail.com     Uber         BIKE              good
# 28504   yogesh.chaudhary@@gmail.com  Rapido          Auto              Good
#
#       experience_level  ... driving_test_score_10 route_knowledge_score_10  \
# 30320           5+ yrs  ...                   6.8                      6.6
# 1286                na  ...                   4.2                     10.6
# 14922          Fresher  ...                   9.1                      4.4
# 4132           Fresher  ...                   4.1                      9.5
# 15089           0-1 yr  ...                   7.8                      6.7
# ...                ...  ...                   ...                      ...
# 786            1-3 yrs  ...                  <NA>                      8.0
# 23059          1-3 yrs  ...                   9.9                      8.1
# 46657          1-3 yrs  ...                   7.8                      4.7
# 8350                na  ...                   4.8                      5.2
# 28504           0-1 yr  ...                   6.2                     -1.1
#
#       customer_handling_score_10 overall_interview_score_10  \
# 30320                        8.2                        6.2
# 1286                         5.5                        5.6
# 14922                        9.7                        6.8
# 4132                         9.2                        NaN
# 15089                        7.3                        7.8
# ...                          ...                        ...
# 786                          NaN                       11.2
# 23059                        7.3                        8.5
# 46657                        NaN                        NaN
# 8350                         4.4                        5.1
# 28504                        3.1                       10.4
#
#        document_verification  background_check_status  interview_result  \
# 30320                   Pass                  Flagged               NaN
# 1286                    pass                    Clear          Rejected
# 14922                   Pass                  Pending          Selected
# 4132                    Fail                      NaN          Rejected
# 15089                    NaN                      NaN               NaN
# ...                      ...                      ...               ...
# 786                     Pass                  FLAGGED           On Hold
# 23059                   Pass                  Flagged               NaN
# 46657                pending                  Flagged          Rejected
# 8350                    FAIL                  Flagged               NaN
# 28504                   pass                    clear           On Hold
#
#            rejection_reason   onboarding_date  is_currently_active
# 30320                   NaN          06/07/22                 true
# 1286         Not applicable                 -                   no
# 14922                   NaN        23-03-2022                False
# 4132                   none                 -                    Y
# 15089  Incomplete documents               NaN                   no
# ...                     ...               ...                  ...
# 786                     NaN               NaN                    N
# 23059                   NaN  11 December 2022                    Y
# 46657   Failed driving test               NaN                   no
# 8350                    NaN          02/24/23                    N
# 28504                   NaN                 -                 true
#
# [1000 rows x 33 columns]

# %%
df['route_knowledge_score_10'].unique()
# Out:
# <StringArray>
# [ '5.8',  '7.5',  '9.0',  '9.6',  '6.5',  '8.6',  '8.7',  '6.4',  '7.9',
#   '7.7',
#  ...
#  '11.4',  '0.5', '12.5',  '1.7',  '1.6',  '0.1', '10.6', '12.6',  '0.6',
#  '11.6']
# Length: 121, dtype: string

# %%
## This converts the data type from object to string.
df['route_knowledge_score_10'] = df['route_knowledge_score_10'].astype("string")
print(df['route_knowledge_score_10'].dtype)
# Out:
# string

# %%
## This is to remove the negative values and also the yrs in the age column.
df['route_knowledge_score_10'] = df['route_knowledge_score_10'].str.lstrip('-')
df.sample(1000)
# Out:
#        driver_id    driver_name  age       city         phone  \
# 45245  DRV012605     Vikram Rao   36    Chennai    9506757843
# 13555  DRV042091   PRADEEP NAIR   26    Kolkata    9974022016
# 12368  DRV009317   Manoj Sharma   70  Ahmedabad    9599459050
# 42661  DRV040459    Umesh Kumar   37  Ahmedabad    9315551146
# 49238  DRV008259  S@nj@y P@ndey   37    Lucknow    9952014557
# ...          ...            ...  ...        ...           ...
# 3897   DRV000146   Hitesh Verma  -26  Hyderabad    9028420353
# 15802  DRV005640  Vikram Tiwari   29    Lucknow  +91197304238
# 42294  DRV021610  Deepak Sharma   45  Hyderabad    9426863098
# 10215  DRV036028  Pradeep Kumar   36       Pune    9832350429
# 13783  DRV017080   NARESH YADAV   55    Chennai  +91749185096
#
#                              email       platform vehicle_type  \
# 45245    vikram.rao@rediffmail.com          Uber          auto
# 13555     pradeep.nair@hotmail.com         Rapido         Mini
# 12368     manoj.sharma@hotmail.com  Uber & rapido        Mini
# 42661   umesh.kumar@rediffmail.com          Uber           SUV
# 49238        sanjay.pandey@hotmail        Rapido          Bike
# ...                            ...            ...          ...
# 3897      hitesh.verma@hotmail.com           Uber         Mini
# 15802      vikram.tiwari@gmail.com         Rapido         Auto
# 42294    deepak.sharma@hotmail.com           Bolt         BIKE
# 10215       pradeep.kumargmail.com            Ola          NaN
# 13783  naresh.yadav@rediffmail.com           Uber         auto
#
#       vehicle_condition experience_level  ... driving_test_score_10  \
# 45245              Poor           0-1 yr  ...                   7.4
# 13555              Good           5+ yrs  ...                   5.0
# 12368              Poor           5+ yrs  ...                   8.4
# 42661           Average           5+ yrs  ...                  <NA>
# 49238              GOOD           0-1 yr  ...                   1.3
# ...                 ...              ...  ...                   ...
# 3897                NaN          1-3 yrs  ...                   4.7
# 15802              poor           0-1 yr  ...                   9.4
# 42294         excellent           0-1 yr  ...                   8.9
# 10215              GOOD          unknown  ...                   4.6
# 13783         Excellent          Fresher  ...                   7.4
#
#       route_knowledge_score_10 customer_handling_score_10  \
# 45245                     <NA>                        7.1
# 13555                      9.1                        3.2
# 12368                      7.3                        NaN
# 42661                     <NA>                        4.7
# 49238                      6.1                        4.4
# ...                        ...                        ...
# 3897                       7.5                        5.5
# 15802                      5.5                        7.1
# 42294                      4.0                        5.8
# 10215                      4.8                        4.8
# 13783                     <NA>                        7.4
#
#       overall_interview_score_10  document_verification  \
# 45245                        6.9                pending
# 13555                       12.3                    NaN
# 12368                        6.8                    NaN
# 42661                        6.2                   pass
# 49238                        5.9                Pending
# ...                          ...                    ...
# 3897                         NaN                pending
# 15802                        7.6                     na
# 42294                        6.8                   Fail
# 10215                        4.6                Unknown
# 13783                        5.8                pending
#
#        background_check_status  interview_result         rejection_reason  \
# 45245                        -                 -                      NaN
# 13555                      NaN          Selected                        -
# 12368                  Pending                na       Poor communication
# 42661                  Flagged          Selected                      NaN
# 49238                    Clear          Rejected  Background check failed
# ...                        ...               ...                      ...
# 3897                   pending           On Hold                      NaN
# 15802                  Flagged          Selected                      NaN
# 42294                      NaN          Rejected      Vehicle age too old
# 10215                      NaN          Rejected  Background check failed
# 13783                  Flagged          Selected                      NaN
#
#             onboarding_date  is_currently_active
# 45245  2022-09-22T00:00:00Z                  YES
# 13555          January 2023                False
# 12368                   NaN                    1
# 42661           August 2021                    N
# 49238                   NaN                    1
# ...                     ...                  ...
# 3897                    NaN                    1
# 15802      22 November 2023                false
# 42294                     -                  Yes
# 10215                   NaN                   no
# 13783            21-02-2021                  YES
#
# [1000 rows x 33 columns]

# %%
df['route_knowledge_score_10'] = df['route_knowledge_score_10'].fillna('7.5')

# %%
## This code fills the age column where NaN values exist with random values between 0 and 10

import numpy as np

mask = df['customer_handling_score_10'] == 6

df.loc[mask, 'customer_handling_score_10'] = np.random.randint(
    0, 10, size=mask.sum()
)
df.sample(1000)
# Out:
#        driver_id      driver_name  age       city         phone  \
# 46914  DRV001146     rajesh reddy   24    Kolkata    9589304016
# 14355  DRV037707     Bharat Dubey   39       Pune    9250731386
# 6282   DRV009517    Girish Mishr@   35     Mumbai    9070854040
# 31287  DRV005661    Hitesh Mishra   38       Pune    9496678565
# 12512  DRV043298     Mahesh Verma   43    Kolkata    9358625267
# ...          ...              ...  ...        ...           ...
# 4518   DRV029962    Santosh Rao     35    Kolkata  +91365604809
# 17542  DRV021920    naresh sharma   26    Chennai       9750486
# 49352  DRV031007      S@nj@y N@ir  -29  Hyderabad    9425457776
# 26687  DRV040077     girish patel   47    Kolkata  +91956456259
# 245    DRV014544    vikram mishra   21    Lucknow    9457004997
#
#                               email       platform vehicle_type  \
# 46914        rajesh.reddy@gmail.com           Uber          suv
# 14355  bharat.dubey@@rediffmail.com           Uber         auto
# 6282      girish.mishra@hotmail.com           Uber          SUV
# 31287     hitesh.mishra@hotmail.com           Uber          suv
# 12512        mahesh.verma@yahoo.com           Bolt         Auto
# ...                             ...            ...          ...
# 4518        santosh.rao@hotmail.com         Rapido        sedan
# 17542       naresh sharma@gmail.com  Uber & rapido         BIKE
# 49352         sanjay.nair@yahoo.com        Rapido         Sedan
# 26687        girish.patel@gmail.com           Uber          SUV
# 245         vikram.mishra@yahoo.com         Rapido         Auto
#
#       vehicle_condition experience_level  ... driving_test_score_10  \
# 46914               avg           5+ yrs  ...                   9.8
# 14355              GOOD           0-1 yr  ...                   7.8
# 6282            Average           5+ yrs  ...                   4.1
# 31287              poor          3-5 yrs  ...                   0.5
# 12512               NaN          3-5 yrs  ...                  <NA>
# ...                 ...              ...  ...                   ...
# 4518                avg           5+ yrs  ...                   4.1
# 17542              good           0-1 yr  ...                   6.4
# 49352         excellent           5+ yrs  ...                   7.8
# 26687              good          1-3 yrs  ...                   7.0
# 245                good          3-5 yrs  ...                   9.5
#
#       route_knowledge_score_10 customer_handling_score_10  \
# 46914                      4.1                        NaN
# 14355                      3.8                        3.5
# 6282                       7.6                       11.3
# 31287                      7.3                        8.1
# 12512                      6.7                        9.3
# ...                        ...                        ...
# 4518                      10.0                        3.5
# 17542                      6.1                        5.6
# 49352                      3.0                        9.3
# 26687                      9.1                        3.7
# 245                       11.7                        8.8
#
#       overall_interview_score_10  document_verification  \
# 46914                        7.4                    NaN
# 14355                        4.9                   FAIL
# 6282                        12.6                    NaN
# 31287                        6.7                   none
# 12512                        7.1                   FAIL
# ...                          ...                    ...
# 4518                         6.5                Pending
# 17542                        5.3                   Pass
# 49352                       11.4                pending
# 26687                        6.9                   Fail
# 245                          8.6                    NaN
#
#        background_check_status  interview_result     rejection_reason  \
# 46914                      NaN          REJECTED                  NaN
# 14355                  pending          Rejected   Low rating history
# 6282                       NaN          Rejected                  NaN
# 31287                    Clear          Rejected                  NaN
# 12512                  pending          Selected                  NaN
# ...                        ...               ...                  ...
# 4518                   pending           On Hold                  NaN
# 17542                  FLAGGED          Rejected  Failed driving test
# 49352                      NaN           On Hold                  NaN
# 26687                  FLAGGED          Selected                  NaN
# 245                      clear           On Hold                  NaN
#
#             onboarding_date  is_currently_active
# 46914            19.11.2021                    1
# 14355                   NaN                    1
# 6282                      -                    0
# 31287                   NaN                  Yes
# 12512                   NaN                  YES
# ...                     ...                  ...
# 4518   2023-07-11T00:00:00Z                    Y
# 17542                   NaN                   No
# 49352                   NaN                False
# 26687            31.08.2023                  Yes
# 245                       -                    Y
#
# [1000 rows x 33 columns]

# %%
df['vehicle_type'].unique()
# Out:
# <StringArray>
# [      'Auto',      'Mini ',        'Suv',       'Mini',       'Bike',
#       'Sedan',   'Tricycle',  'Motorbike',    'Bicycle', 'Catapiller',
#       'Truck']
# Length: 11, dtype: string

# %%
## This converts the data type from object to string.
df['vehicle_type'] = df['vehicle_type'].astype("string")
print(df['vehicle_type'].dtype)
# Out:
# string

# %%
df['vehicle_type'] = df['vehicle_type'].str.capitalize()
df['vehicle_type'] = df['vehicle_type'].fillna('Motorbike')
df['vehicle_type'] = df['vehicle_type'].replace({
   #'NaN': '70',
   # 'Mini ': 'Trailer',
    #'unknown': '80',
    #'999' : '90',
    #'Unknown': 'Experienced',
    'None': 'Bicycle',
    #'Avg': 'Average',
    #'poor': 'Super',
    'Unknown': 'Tricycle',
    'Na': 'Catapiller',
    '-': 'Truck',
    #"<NA>": 'Bus',
    #'Auto': '',
    #'suv' : 'SUV'
    #'uber': '',
    #'<NA>': '6'
})
df.sample(10000)
# Out:
#        driver_id      driver_name age       city         phone  \
# 15709  DRV024545  N@resh Trip@thi  28  Hyderabad    9833614369
# 36424  DRV000100    Deepak Mishra  33  Hyderabad    9075183612
# 7931   DRV008571     VIKRAM VERMA  42    Kolkata  +91496995590
# 42227  DRV019126     Pankaj Reddy  23      Delhi  +91846149162
# 45952  DRV037556     Harish Dubey  49     Jaipur       9497670
# ...          ...              ...  ..        ...           ...
# 39301  DRV002154   ramesh chauhan  37      Delhi    9487794357
# 3317   DRV043874   Vikram Chauhan  35     Mumbai    9902050398
# 48205  DRV000479    Vikram Shukla  30      Delhi  +91989231903
# 12122  DRV013724   Santosh Sharma  45  Ahmedabad  +91408423573
# 33003  DRV028511      Rajesh Nair  28    Chennai    9588571531
#
#                                email       platform vehicle_type  \
# 15709      N@resh Trip@thi@gmail.com         Rapido          Suv
# 36424      deepak.mishra@hotmail.com            Ola         Bike
# 7931        vikram.verma@hotmail.com            Ola        Mini
# 42227         pankaj.reddy@yahoo.com             Na        Mini
# 45952    harish.dubey@rediffmail.com           Uber          Suv
# ...                              ...            ...          ...
# 39301      ramesh.chauhan@@gmail.com          Uber          Bike
# 3317      vikram.chauhan@hotmail.com  Uber & rapido         Auto
# 48205        vikram.shukla@yahoo.com        Rapido          Auto
# 12122  santosh.sharma@rediffmail.com           Uber          Suv
# 33003          Rajesh Nair@gmail.com        Rapido       Bicycle
#
#       vehicle_condition experience_level  ... driving_test_score_10  \
# 15709              Good           5+ yrs  ...                   9.9
# 36424              GOOD          1-3 yrs  ...                   5.1
# 7931                NaN          1-3 yrs  ...                   6.7
# 42227              GOOD           0-1 yr  ...                   8.3
# 45952         excellent           0-1 yr  ...                  10.8
# ...                 ...              ...  ...                   ...
# 39301              good          3-5 yrs  ...                   7.9
# 3317                avg          3-5 yrs  ...                   5.1
# 48205           Unknown          Fresher  ...                   6.8
# 12122               NaN          1-3 yrs  ...                   6.5
# 33003               NaN          Fresher  ...                   6.9
#
#       route_knowledge_score_10 customer_handling_score_10  \
# 15709                      7.1                        8.7
# 36424                      5.9                       -0.2
# 7931                       3.1                        7.0
# 42227                      7.7                       11.5
# 45952                      5.9                        6.1
# ...                        ...                        ...
# 39301                      6.6                       12.1
# 3317                       5.0                        5.1
# 48205                      7.2                        6.5
# 12122                      4.2                        7.5
# 33003                      9.5                        3.0
#
#       overall_interview_score_10  document_verification  \
# 15709                        8.9                   pass
# 36424                        6.1                pending
# 7931                        12.4                   pass
# 42227                        5.6                    NaN
# 45952                        7.5                    NaN
# ...                          ...                    ...
# 39301                        6.7                   FAIL
# 3317                         5.8                   Fail
# 48205                        NaN                   FAIL
# 12122                        NaN                pending
# 33003                        7.2                    NaN
#
#        background_check_status  interview_result    rejection_reason  \
# 15709                  Flagged          Waitlist                 NaN
# 36424                  Unknown          Waitlist                 NaN
# 7931                   Pending           On Hold                 NaN
# 42227                  Pending           On Hold                 NaN
# 45952                  Pending          Selected                 NaN
# ...                        ...               ...                 ...
# 39301                  Flagged          Rejected  Poor communication
# 3317                     Clear          Selected                 NaN
# 48205                  Pending           On Hold                 NaN
# 12122                    clear               NaN                 NaN
# 33003                      NaN          Rejected  Low rating history
#
#        onboarding_date  is_currently_active
# 15709         May 2023                    Y
# 36424    February 2024                false
# 7931                 -                  Yes
# 42227                -                 True
# 45952     16 July 2023                   NO
# ...                ...                  ...
# 39301                -                    N
# 3317               NaN                  yes
# 48205              NaN                   no
# 12122                -                 True
# 33003              NaN                 True
#
# [10000 rows x 33 columns]

# %%
df['vehicle_condition'].unique()
# Out:
# <StringArray>
# [     'Good', 'Excellent',   'Average',     'Super',      'Poor',     'Great',
#  'Wonderful',      'Fair', 'Beautiful']
# Length: 9, dtype: string

# %%
## This converts the data type from object to string.
df['vehicle_condition'] = df['vehicle_condition'].astype("string")
print(df['vehicle_condition'].dtype)
# Out:
# string

# %%
df['vehicle_condition'] = df['vehicle_condition'].str.capitalize()
df['vehicle_condition'] = df['vehicle_condition'].fillna('Super')
df['vehicle_condition'] = df['vehicle_condition'].replace({
   #'NaN': '70',
   # 'Mini ': 'Trailer',
    #'unknown': '80',
    #'999' : '90',
    'Unknown': 'Great',
    'None': 'Beautiful',
    'Avg': 'Average',
    #'poor': 'Super',
    #'Unknown': 'Tricycle',
    'Na': 'Fair',
    '-': 'Wonderful',
    #"<NA>": 'Bus',
    #'Auto': '',
    #'suv' : 'SUV'
    #'uber': '',
    #'<NA>': '6'
})
df.sample(10000)
# Out:
#        driver_id       driver_name  age       city         phone  \
# 19679  DRV017672  Naveen Chaudhary  -37  Ahmedabad    9141380835
# 41342  DRV047342       anil sharma   46    Chennai    9102565640
# 279    DRV031630      Umesh Tiwari   31    Lucknow    9742330931
# 13759  DRV042943     Bharat Tiwari   32    Kolkata  +91488774776
# 49118  DRV043837   HITESH TRIPATHI   42    Lucknow  +91440912384
# ...          ...               ...  ...        ...           ...
# 17631  DRV038428    PRADEEP SHUKLA   26     Mumbai    9210742155
# 2841   DRV036444        RAKESH RAO   25    Chennai    9676268406
# 48659  DRV028265      Rakesh Yadav  999    Kolkata  +91053536148
# 32334  DRV030680      Vikram Gupta   45       Pune    9494634606
# 34877  DRV008313     Hitesh Mishra   22       Pune    9562357717
#
#                                email       platform vehicle_type  \
# 19679   naveen.chaudhary@hotmail.com          Uber          Auto
# 41342         anil.sharma@rediffmail           Uber    Motorbike
# 279         umesh.tiwari@hotmail.com  Uber & rapido        Mini
# 13759            bharat.tiwari@yahoo           Uber        Mini
# 49118    hitesh.tripathi@hotmail.com        Rapido           Suv
# ...                              ...            ...          ...
# 17631  pradeep.shukla@rediffmail.com              -         Mini
# 2841          rakesh.rao@hotmail.com         Rapido          Suv
# 48659         rakesh.yadav@yahoo.com        Rapido          Auto
# 32334       vikram.gupta@hotmail.com         Rapido        Sedan
# 34877   hitesh.mishra@rediffmail.com           Uber        Mini
#
#       vehicle_condition experience_level  ... driving_test_score_10  \
# 19679              Poor          3-5 yrs  ...                   9.5
# 41342              Poor              NaN  ...                   9.8
# 279                Good          1-3 yrs  ...                   7.6
# 13759              Poor          1-3 yrs  ...                   8.1
# 49118           Average          Fresher  ...                   5.7
# ...                 ...              ...  ...                   ...
# 17631              Poor          3-5 yrs  ...                   4.2
# 2841               Poor          Fresher  ...                   0.7
# 48659              Poor          Unknown  ...                  <NA>
# 32334             Super          Fresher  ...                   4.9
# 34877             Super          Fresher  ...                   6.7
#
#       route_knowledge_score_10 customer_handling_score_10  \
# 19679                      5.6                        7.7
# 41342                      7.5                        5.5
# 279                        5.4                        6.6
# 13759                      6.9                        3.6
# 49118                      4.8                        5.9
# ...                        ...                        ...
# 17631                      4.9                        6.9
# 2841                       4.7                        4.7
# 48659                      5.6                        3.5
# 32334                      9.3                        NaN
# 34877                     10.0                       12.6
#
#       overall_interview_score_10  document_verification  \
# 19679                        6.6                   Fail
# 41342                        7.1                Pending
# 279                         10.7                    NaN
# 13759                        6.7                    NaN
# 49118                        6.2                   FAIL
# ...                          ...                    ...
# 17631                        6.2                   FAIL
# 2841                         5.9                   FAIL
# 48659                        NaN                    NaN
# 32334                        NaN                   Fail
# 34877                        7.8                   pass
#
#        background_check_status  interview_result         rejection_reason  \
# 19679                    Clear           On Hold                      NaN
# 41342                      NaN              none                      NaN
# 279                      clear           on hold                      NaN
# 13759                      NaN          Rejected  Background check failed
# 49118                  Pending          Rejected                      NaN
# ...                        ...               ...                      ...
# 17631                      NaN          Selected                      NaN
# 2841                   pending               NaN                      NaN
# 48659                      NaN          Rejected  Background check failed
# 32334                  Flagged               NaN                      NaN
# 34877                  Flagged               NaN      Vehicle age too old
#
#        onboarding_date  is_currently_active
# 19679              NaN                    1
# 41342                -                    1
# 279                NaN                 true
# 13759              NaN                   NO
# 49118              NaN                    1
# ...                ...                  ...
# 17631       April 2024                    0
# 2841       07 May 2022                    N
# 48659              NaN                  YES
# 32334              NaN                    1
# 34877              NaN                    Y
#
# [10000 rows x 33 columns]
