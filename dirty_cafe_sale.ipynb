# %%
import pandas as pd

import matplotlib.pyplot as plt

df = pd.read_csv("dirty_cafe_sales.csv")
df.head(10)
# Out:
#   Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0    TXN_1961373    Coffee        2            2.0         4.0
# 1    TXN_4977031      Cake        4            3.0        12.0
# 2    TXN_4271903    Cookie        4            1.0       ERROR
# 3    TXN_7034554     Salad        2            5.0        10.0
# 4    TXN_3160411    Coffee        2            2.0         4.0
# 5    TXN_2602893  Smoothie        5            4.0        20.0
# 6    TXN_4433211   UNKNOWN        3            3.0         9.0
# 7    TXN_6699534  Sandwich        4            4.0        16.0
# 8    TXN_4717867       NaN        5            3.0        15.0
# 9    TXN_2064365  Sandwich        5            4.0        20.0
#
#    Payment Method  Location Transaction Date
# 0     Credit Card  Takeaway       2023-09-08
# 1            Cash  In-store       2023-05-16
# 2     Credit Card  In-store       2023-07-19
# 3         UNKNOWN   UNKNOWN       2023-04-27
# ...

# %%
df.describe()
# Out:
#        Transaction ID   Item Quantity Price Per Unit Total Spent  \
# count           10000   9667     9862           9821        9827
# unique          10000     10        7              8          19
# top       TXN_6170729  Juice        5            3.0         6.0
# freq                1   1171     2013           2429         979
#
#         Payment Method  Location Transaction Date
# count             7421      6735             9841
# unique               5         4              367
# top     Digital Wallet  Takeaway          UNKNOWN
# freq              2291      3022              159

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    10000 non-null  object
#  1   Item              9667 non-null   object
#  2   Quantity          9862 non-null   object
#  3   Price Per Unit    9821 non-null   object
#  4   Total Spent       9827 non-null   object
#  5   Payment Method    7421 non-null   object
#  6   Location          6735 non-null   object
#  7   Transaction Date  9841 non-null   object
# dtypes: object(8)
# memory usage: 625.1+ KB

# %%
df.sample(7000)
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 5946    TXN_2551378       Tea        2            1.5         3.0
# 2636    TXN_2576799     Juice        1            3.0         3.0
# 9703    TXN_9335226  Sandwich        5            4.0        20.0
# 6328    TXN_7838576    Coffee        3            2.0         6.0
# 5303    TXN_1197536     Salad        3            5.0        15.0
# ...             ...       ...      ...            ...         ...
# 1298    TXN_6411716      Cake        4            3.0        12.0
# 7518    TXN_7482834  Sandwich  UNKNOWN            4.0        20.0
# 3169    TXN_8359674     Salad        3            5.0        15.0
# 2461    TXN_8031804    Coffee        4            2.0         8.0
# 3473    TXN_1818438    Coffee        5            2.0        10.0
#
#      Payment Method  Location Transaction Date
# 5946            NaN  Takeaway       2023-10-27
# 2636           Cash       NaN       2023-03-12
# ...

# %%
df["Item"] = df["Item"].astype(str)

# %%
df["Item"] = df["Item"].replace("nan", 'Egg')
df.sample(5000)
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 8541    TXN_2585392     Salad        4            5.0        20.0
# 5750    TXN_4392519    Cookie        2            1.0         2.0
# 2279    TXN_3507334     Juice        4            3.0        12.0
# 2493    TXN_3226989     Salad        1            5.0         5.0
# 9851    TXN_2738904  Smoothie        4            4.0        16.0
# ...             ...       ...      ...            ...         ...
# 6557    TXN_3232043       Tea        2            1.5         3.0
# 8619    TXN_4597600    Cookie        5            1.0         NaN
# 6161    TXN_2541441      Cake        1            3.0         3.0
# 7720    TXN_6540200       Tea        2            1.5         3.0
# 1820    TXN_5460750     Juice        3            3.0         9.0
#
#       Payment Method  Location Transaction Date
# 8541             NaN       NaN       2023-07-12
# 5750         UNKNOWN  Takeaway       2023-09-20
# ...

# %%
df.shape
# Out:
# (10000, 8)

# %%
df['Quantity']
# Out:
# 0       2
# 1       4
# 2       4
# 3       2
# 4       2
#        ..
# 9995    2
# 9996    3
# 9997    4
# 9998    3
# 9999    3
# Name: Quantity, Length: 10000, dtype: object

# %%
df["Quantity"] = df["Quantity"].replace("nan", "7.1")
df.sample(7000)
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 8831    TXN_4008899     Salad        4            5.0        20.0
# 508     TXN_2641386  Sandwich        3            4.0        12.0
# 1643    TXN_7350571  Smoothie        1            4.0         4.0
# 8315    TXN_1569729  Smoothie        5            4.0        20.0
# 4197    TXN_4391496  Sandwich        1            4.0         4.0
# ...             ...       ...      ...            ...         ...
# 4869    TXN_4341126      Cake        2            3.0         6.0
# 3981    TXN_3776109   UNKNOWN        1            5.0         5.0
# 222     TXN_7433461    Cookie        2            1.0         2.0
# 4721    TXN_8397209   UNKNOWN        3            1.5         4.5
# 1496    TXN_6738350     Juice        2            3.0         6.0
#
#       Payment Method  Location Transaction Date
# 8831             NaN       NaN       2023-05-07
# 508          UNKNOWN  Takeaway       2023-03-25
# ...

# %%
df["Payment Method"] = df["Payment Method"].replace("UNKNOWN", "Paypal")
df.sample(1000)
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 5787    TXN_5093312    Cookie        4            1.0         4.0
# 6182    TXN_1606273    Coffee        1            2.0         2.0
# 4709    TXN_9428611     Salad        4            5.0        20.0
# 2904    TXN_6212975       Egg        1            4.0         4.0
# 7827    TXN_6043396  Sandwich        3            4.0        12.0
# ...             ...       ...      ...            ...         ...
# 6579    TXN_9409405     ERROR        3            2.0         6.0
# 9654    TXN_6474636       Egg        3            1.5         4.5
# 4019    TXN_6814891    Coffee        1            2.0         2.0
# 276     TXN_2078474    Cookie        2            1.0         2.0
# 3264    TXN_5901182  Sandwich        5            4.0        20.0
#
#       Payment Method  Location Transaction Date
# 5787     Credit Card  Takeaway       2023-08-12
# 6182  Digital Wallet  Takeaway       2023-11-02
# ...

# %%
df["Price Per Unit"] = df["Price Per Unit"].replace("NaN", "5.0")
df.sample(7000)
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 8468    TXN_5556985     Juice        3            3.0         9.0
# 2393    TXN_5609260    Cookie        5            1.0         5.0
# 6551    TXN_1199898  Smoothie        1            4.0         4.0
# 1180    TXN_4176373    Cookie        3            1.0         3.0
# 896     TXN_5934059     Juice      NaN            3.0        12.0
# ...             ...       ...      ...            ...         ...
# 9819    TXN_1208561       Egg    ERROR            NaN        20.0
# 4349    TXN_3587444     Juice        2            3.0         6.0
# 4084    TXN_1700027  Smoothie        4            4.0        16.0
# 5026    TXN_3841683  Sandwich        1            4.0         4.0
# 1029    TXN_5654490       Tea        4            1.5         6.0
#
#       Payment Method  Location Transaction Date
# 8468  Digital Wallet  In-store            ERROR
# 2393  Digital Wallet  In-store       2023-05-02
# ...

# %%
df["Total Spent"] = df["Total Spent"].replace("nan", "14.0")
df.sample(7000)
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 8944    TXN_6014389    Cookie        5            1.0         5.0
# 2096    TXN_7415686  Sandwich        3            4.0        12.0
# 4347    TXN_1583315    Cookie        3            1.0         3.0
# 811     TXN_2840323       Tea        4            1.5         6.0
# 7985    TXN_7221831    Coffee        3            2.0         6.0
# ...             ...       ...      ...            ...         ...
# 6045    TXN_7171590    Coffee        3            2.0         6.0
# 9193    TXN_3418612       Tea        3            1.5         4.5
# 2202    TXN_5855981     Juice        2            3.0         6.0
# 406     TXN_7809183     ERROR        4            1.0         4.0
# 5035    TXN_2784588     Juice        2            3.0         6.0
#
#       Payment Method  Location Transaction Date
# 8944     Credit Card  In-store       2023-07-21
# 2096     Credit Card  In-store       2023-04-13
# ...

# %%
df["Payment Method"] = df["Payment Method"].replace("nan", "Bitcoin")
df.sample(10000)
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 1869    TXN_2699583  Sandwich        5            4.0        20.0
# 1261    TXN_3713976     Juice        2            3.0         6.0
# 6092    TXN_2510233     ERROR        2            4.0         8.0
# 7433    TXN_9215670    Coffee        3            NaN         6.0
# 5825    TXN_5452210       Tea        5            1.5         7.5
# ...             ...       ...      ...            ...         ...
# 6602    TXN_1196324       Tea        4            1.5         6.0
# 7217    TXN_6266750  Sandwich        1            4.0         4.0
# 2320    TXN_3446033    Cookie        3            1.0         3.0
# 7751    TXN_4719069     Juice        2            3.0         6.0
# 7513    TXN_4283693     Salad        2            5.0        10.0
#
#       Payment Method  Location Transaction Date
# 1869  Digital Wallet  In-store       2023-07-26
# 1261             NaN  Takeaway       2023-11-06
# ...

# %%
df["Location"] = df["Location"].astype(str)
#This code will help to normalize the quantity column to an integer.

# %%
df["Location"] = df["Location"].replace('nan', "Appstore")
df.sample(7000)
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 4863    TXN_4697112  Sandwich        3            4.0        12.0
# 3651    TXN_1733916  Sandwich        4            4.0        16.0
# 6201    TXN_9300618       Tea        3            1.5         4.5
# 9171    TXN_9811007    Cookie        5            1.0         5.0
# 4512    TXN_8367716       Tea        2            1.5         3.0
# ...             ...       ...      ...            ...         ...
# 2293    TXN_2291713     Salad        4            5.0        20.0
# 7598    TXN_2530326  Sandwich        5            4.0        20.0
# 6148    TXN_9579740      Cake        3            3.0         9.0
# 7726    TXN_9685716    Cookie        2            1.0         2.0
# 4121    TXN_2817018  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 4863     Credit Card  Appstore       2023-04-08
# 3651  Digital Wallet  In-store       2023-01-12
# ...

# %%
df["Location"] = df["Location"].replace('nan', "Appstore")
df.sample(7000)
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 1733    TXN_2540440       Egg        2            1.5         3.0
# 7428    TXN_4477016  Sandwich        4            4.0         NaN
# 6236    TXN_1328953  Smoothie        3            4.0        12.0
# 201     TXN_6749847      Cake        2            3.0         6.0
# 7204    TXN_1072984       Tea        4            1.5         6.0
# ...             ...       ...      ...            ...         ...
# 1007    TXN_7615147  Sandwich        4            4.0        16.0
# 2147    TXN_9104535      Cake        4            3.0         NaN
# 5463    TXN_6806024     Juice      NaN            3.0         6.0
# 5230    TXN_8534360     Juice        5            3.0        15.0
# 4641    TXN_7047860    Coffee        2            NaN         4.0
#
#       Payment Method  Location Transaction Date
# 1733  Digital Wallet  Appstore       2023-12-30
# 7428             NaN  In-store       2023-04-12
# ...

# %%
df['Location'].unique()
# Out:
# array(['Takeaway', 'In-store', 'UNKNOWN', 'Appstore', 'ERROR'],
#       dtype=object)

# %%
df['Item'] = df['Item'].replace({
    'UNKNOWN': 'Bread',
    'ERROR': 'Milk'
})
df.sample(7000)
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 8854    TXN_4413197       Tea        4            1.5         6.0
# 578     TXN_4498526  Smoothie        3            4.0        12.0
# 533     TXN_2690314       Tea        5            1.5         7.5
# 8270    TXN_8886791       Tea        2            1.5         3.0
# 116     TXN_1535311     Juice        3            3.0         9.0
# ...             ...       ...      ...            ...         ...
# 7093    TXN_6125085     Bread        3            3.0         9.0
# 6107    TXN_9921708      Cake        1            3.0         3.0
# 1740    TXN_6987950      Cake        4            3.0        12.0
# 5734    TXN_9399452      Cake        4            3.0        12.0
# 8521    TXN_9162014      Cake        1            3.0         3.0
#
#       Payment Method  Location Transaction Date
# 8854  Digital Wallet  Appstore       2023-09-06
# 578      Credit Card  Appstore       2023-06-20
# ...

# %%
df['Quantity'] = df['Quantity'].replace({
    'UNKNOWN': '7',
    'ERROR': '8',
    'NaN' : '9'
})
df.sample(7000)
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 729     TXN_1347965    Cookie        5            1.0         5.0
# 8515    TXN_3028667     Juice        2            3.0         6.0
# 9551    TXN_7785034  Smoothie        4            4.0        16.0
# 8969    TXN_6488040     Salad        1            5.0       ERROR
# 1902    TXN_4917580      Milk        3            2.0         6.0
# ...             ...       ...      ...            ...         ...
# 202     TXN_2143187  Smoothie        1            4.0         4.0
# 8583    TXN_9869593      Cake        2            3.0         6.0
# 9775    TXN_3224397    Cookie        4            1.0         4.0
# 3773    TXN_6739950     Salad        8            5.0        20.0
# 1108    TXN_5033045     Salad        3            5.0        15.0
#
#       Payment Method  Location Transaction Date
# 729           Paypal  In-store       2023-02-19
# 8515             NaN  Takeaway       2023-11-24
# ...

# %%
df['Price Per Unit'] = df['Price Per Unit'].replace({
    'UNKNOWN': '8.0',
    'ERROR': '9.0'
})
df.sample(7000)
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 3137    TXN_5632564    Cookie        1            1.0         1.0
# 1187    TXN_5386752     Salad        4            5.0        20.0
# 6909    TXN_1811216  Sandwich        1            4.0         4.0
# 304     TXN_7922392  Sandwich        3            4.0        12.0
# 16      TXN_3765707  Sandwich        1            4.0         4.0
# ...             ...       ...      ...            ...         ...
# 5580    TXN_6154823      Milk        5            4.0        20.0
# 5495    TXN_4831345  Sandwich        5            4.0        20.0
# 1351    TXN_6086709      Milk        5            3.0        15.0
# 1731    TXN_2463115  Sandwich        5            4.0        20.0
# 1411    TXN_9278992  Smoothie        4            4.0        16.0
#
#       Payment Method  Location Transaction Date
# 3137     Credit Card  Appstore       2023-11-04
# 1187  Digital Wallet  In-store       2023-12-07
# ...

# %%
df['Total Spent'] = df['Total Spent'].replace({
    'UNKNOWN': '11.0',
    'ERROR': '13.0'
})
df.sample(7000)
# Out:
#      Transaction ID    Item Quantity Price Per Unit Total Spent  \
# 1423    TXN_9074075   Juice        5            3.0        15.0
# 7178    TXN_6640488     Tea        3            1.5         4.5
# 1744    TXN_7501002  Coffee        1            2.0         2.0
# 2534    TXN_5707386     Tea        5            1.5         7.5
# 5029    TXN_7786787     Tea        1            1.5         1.5
# ...             ...     ...      ...            ...         ...
# 1786    TXN_1923349    Milk        4            9.0         6.0
# 3876    TXN_8125141     Tea        3            1.5         4.5
# 3754    TXN_9764251  Cookie        4            1.0         4.0
# 1886    TXN_1005331  Coffee        1            2.0         2.0
# 9614    TXN_2875074    Cake        4            3.0        12.0
#
#       Payment Method  Location Transaction Date
# 1423     Credit Card     ERROR       2023-08-14
# 7178     Credit Card  Takeaway       2023-04-01
# 1744  Digital Wallet   UNKNOWN       2023-08-23
# ...

# %%
df['Payment Method'] = df['Payment Method'].replace({
    'nan': 'Bitcoin',
})
df.sample(7000)
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 3702    TXN_3422759     Salad        5            5.0        25.0
# 1941    TXN_4155134    Cookie        1            1.0         1.0
# 2950    TXN_3376958     Salad        4            5.0        20.0
# 5022    TXN_1495371  Sandwich        2            4.0        13.0
# 4716    TXN_7805115  Smoothie        2            4.0         8.0
# ...             ...       ...      ...            ...         ...
# 7762    TXN_5349355       Egg        2            5.0        10.0
# 6766    TXN_9929732  Sandwich        4            4.0        16.0
# 2119    TXN_1655827      Cake        1            3.0         3.0
# 3145    TXN_6539480      Cake        5            3.0        15.0
# 4831    TXN_5926025       Egg        2            4.0         NaN
#
#       Payment Method  Location Transaction Date
# 3702     Credit Card  Takeaway       2023-02-19
# 1941             NaN  Takeaway       2023-05-07
# ...

# %%
df["Location"] = df["Location"].astype(str)
#This code will help to normalize the quantity column to an integer.

# %%
df['Location'] = df['Location'].replace({
    'UNKNOWN': 'Webstore',
    'ERROR': 'Delivery',
    'nan': 'PickUppoint'
})
df.sample(7000)
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 2542    TXN_7107807    Cookie        1            1.0         1.0
# 9648    TXN_3964550       Tea        3            1.5         4.5
# 5978    TXN_1971201  Smoothie        2            4.0         8.0
# 4594    TXN_5665311     Bread        2            1.0         2.0
# 6894    TXN_7866805  Sandwich        3            4.0        12.0
# ...             ...       ...      ...            ...         ...
# 8146    TXN_3514890  Smoothie        5            4.0        20.0
# 952     TXN_2964638     Salad        2            5.0        10.0
# 8969    TXN_6488040     Salad        1            5.0        13.0
# 328     TXN_8319993     Juice        1            3.0         3.0
# 4439    TXN_8917822      Cake        2            3.0         6.0
#
#       Payment Method  Location Transaction Date
# 2542  Digital Wallet  Appstore       2023-11-01
# 9648     Credit Card  Takeaway       2023-06-09
# ...

# %%
df["Transaction Date"] = df["Transaction Date"].astype(str)
#This code will help to normalize the quantity column to an integer.

# %%
df['Transaction Date'] = df['Transaction Date'].replace({
    'UNKNOWN': '2023-05-22',
    'ERROR': '2023-07-27',
    'nan': '2023-09-09'
})
df.sample(7000)
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 392     TXN_2598728      Cake        2            3.0         6.0
# 8234    TXN_5108867       Egg        8            3.0         9.0
# 9665    TXN_4814244  Smoothie        3            4.0        12.0
# 3412    TXN_2797925      Cake        2            3.0        11.0
# 5939    TXN_7986904    Cookie        3            1.0         3.0
# ...             ...       ...      ...            ...         ...
# 4606    TXN_2402928    Coffee        4            2.0         8.0
# 2974    TXN_8571836     Juice        3            NaN         9.0
# 8865    TXN_4565969    Coffee        3            2.0         6.0
# 7704    TXN_5301926      Cake        1            3.0         3.0
# 8665    TXN_3374343      Cake        2            3.0         6.0
#
#       Payment Method  Location Transaction Date
# 392      Credit Card  Appstore       2023-01-13
# 8234            Cash  Takeaway       2023-03-19
# ...

# %%
df.sample(8000)
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 4817    TXN_6687734      Cake        1            3.0         3.0
# 572     TXN_4669664    Cookie        1            1.0         1.0
# 5062    TXN_7560210     Juice        5            3.0        15.0
# 2624    TXN_3187634     Bread        5            2.0        10.0
# 6252    TXN_2919952     Juice      NaN            3.0        15.0
# ...             ...       ...      ...            ...         ...
# 5528    TXN_7151374       Tea        4            1.5         6.0
# 8729    TXN_1786141  Smoothie        4            4.0        16.0
# 1779    TXN_1546695    Coffee        5            2.0         NaN
# 525     TXN_1330506    Cookie        3            1.0         3.0
# 9184    TXN_9077087     Juice        1            3.0         3.0
#
#       Payment Method  Location Transaction Date
# 4817           ERROR  In-store       2023-03-14
# 572   Digital Wallet  In-store       2023-12-21
# ...

# %%
df["Total Spent"] = df["Total Spent"].astype(str)
#This code will help to normalize the quantity column to an integer.

# %%
df['Total Spent'] = df['Total Spent'].replace({
    'nan': '40.0'
})
df.sample(7000)
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 5520    TXN_7605154     Juice        5            3.0        15.0
# 975     TXN_6269119       Egg        2            3.0         6.0
# 7277    TXN_8549600    Coffee      NaN            2.0         6.0
# 6503    TXN_6874059     Salad        4            5.0        20.0
# 5144    TXN_4650611    Coffee        1            2.0         2.0
# ...             ...       ...      ...            ...         ...
# 2026    TXN_5807634  Sandwich        5            4.0        20.0
# 7632    TXN_9430262    Coffee        5            2.0        10.0
# 5644    TXN_8223689     Salad        5            5.0        25.0
# 8011    TXN_6335297      Cake        3            3.0         9.0
# 5961    TXN_4644790     Bread        1            4.0         4.0
#
#       Payment Method  Location Transaction Date
# 5520            Cash  In-store       2023-09-09
# 975   Digital Wallet  Takeaway       2023-07-19
# ...

# %%
df['Payment Method'].unique()
# Out:
# array(['Credit Card', 'Cash', 'Paypal', 'Digital Wallet', 'Emoney',
#        'Bitcoin'], dtype=object)

# %%
df["Payment Method"] = df["Payment Method"].astype(str)
#This code will help to normalize the quantity column to an integer.

# %%
df['Payment Method'] = df['Payment Method'].replace({
    'nan': 'Bitcoin'
})
df.sample(7000)
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 8024    TXN_9731999  Sandwich        8            4.0        16.0
# 7519    TXN_8533584    Cookie        2            1.0         2.0
# 6683    TXN_4032956    Coffee        5            2.0        10.0
# 2620    TXN_8553273     Juice        5            3.0        15.0
# 2198    TXN_5406758      Milk        5            5.0        25.0
# ...             ...       ...      ...            ...         ...
# 5014    TXN_5412418       Egg        3            3.0         9.0
# 526     TXN_5898743     Juice        4            3.0        13.0
# 6618    TXN_5336437       Tea        5            1.5         7.5
# 9666    TXN_7968892       Tea        2            1.5         3.0
# 801     TXN_2393500     Juice        1            9.0         3.0
#
#      Payment Method  Location Transaction Date
# 8024        Bitcoin  Takeaway       2023-11-26
# 7519           Cash  Takeaway       2023-03-11
# ...

# %%
df["Price Per Unit"] = df["Price Per Unit"].astype(str)
#This code will help to normalize the quantity column to an integer.

# %%
df['Price Per Unit'] = df['Price Per Unit'].replace({
    'nan': '7.0'
})
df.sample(7000)
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 3382    TXN_6485220      Cake        3            3.0         9.0
# 4477    TXN_3463281      Cake        5            7.0        15.0
# 745     TXN_1869814       Tea        1            1.5         1.5
# 6850    TXN_4284507  Smoothie        4            4.0        16.0
# 2457    TXN_7716125    Cookie        2            1.0         2.0
# ...             ...       ...      ...            ...         ...
# 2604    TXN_5644235     Salad        4            5.0        20.0
# 1433    TXN_3712466      Cake        5            3.0        11.0
# 6255    TXN_5926432  Smoothie        4            4.0        16.0
# 8618    TXN_5079166     Salad        5            5.0        25.0
# 4650    TXN_3431526    Cookie        3            1.0         3.0
#
#       Payment Method  Location Transaction Date
# 3382            Cash  Delivery       2023-07-27
# 4477             nan  Takeaway       2023-10-06
# ...

# %%
df.sample(10000)
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 4889    TXN_7813066     Juice        1            7.0         3.0
# 1194    TXN_5913013    Cookie        2            1.0         2.0
# 2090    TXN_7694020    Cookie        2            7.0         2.0
# 7740    TXN_2910247  Smoothie        4            4.0        16.0
# 6819    TXN_9890279  Smoothie        4            7.0        16.0
# ...             ...       ...      ...            ...         ...
# 3211    TXN_6022618  Smoothie        1            4.0         4.0
# 1337    TXN_5031214      Milk        5            8.0         5.0
# 4175    TXN_8566668  Sandwich        5            4.0        20.0
# 2226    TXN_6211466       Egg        2            1.5         3.0
# 9702    TXN_5476485     Juice        2            3.0         6.0
#
#       Payment Method  Location Transaction Date
# 4889         Bitcoin  Appstore       2023-02-28
# 1194     Credit Card  Takeaway       2023-11-29
# ...

# %% [markdown]
# Data visualization according to the Quantity of Items sold in particular Locations.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.bar(df['Payment Method'], df["Location"])

plt.title("Payment Method against Location")
plt.xlabel("Payment Method")
plt.ylabel("Location")

plt.show()

# %%
df.dtypes
# Out:
# Transaction ID      object
# Item                object
# Quantity            object
# Price Per Unit      object
# Total Spent         object
# Payment Method      object
# Location            object
# Transaction Date    object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    10000 non-null  object
#  1   Item              10000 non-null  object
#  2   Quantity          9862 non-null   object
#  3   Price Per Unit    10000 non-null  object
#  4   Total Spent       10000 non-null  object
#  5   Payment Method    10000 non-null  object
#  6   Location          10000 non-null  object
#  7   Transaction Date  10000 non-null  object
# dtypes: object(8)
# memory usage: 625.1+ KB

# %% [markdown]
# Visualizing the data with seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(data=df, x='Total Spent')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(data=df, x='Quantity')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(data=df, x='Item', y='Location')
plt.show()

# %%
import seaborn as sns

sns.boxplot(data=df, x='Item')
plt.show()
